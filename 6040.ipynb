# %% [markdown]
# Import Libraries and Packages

# %%
import os
import shutil
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import opendatasets as od
import tensorflow as tf
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %% [markdown]
# Data Extraction

# %%
# Download the dataset
dataset_url = 'https://www.kaggle.com/datasets/msambare/fer2013'
od.download(dataset_url)

# Define dataset paths
train_path = "fer2013/train"
val_path = "fer2013/test"
# Out:
# Skipping, found downloaded files in ".\fer2013" (use force=True to force download)

# %% [markdown]
# Data Pre-Processing

# %%
# Initialize data generators with data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)
val_datagen = ImageDataGenerator(rescale=1./255)

# Load training and validation data
batch_size = 64
target_size = (48, 48)
train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=target_size,
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode='categorical',
    shuffle=True
)
val_generator = val_datagen.flow_from_directory(
    val_path,
    target_size=target_size,
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode='categorical'
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# Define the number of classes
num_classes = 7

model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(256, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

    # Model compilation
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 23, 23, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 21, 21, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)         73856
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 256)         295168
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 512)               131584
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 523,015
# Trainable params: 523,015
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# CNN Algorithm

# %%
# Define the number of classes
num_classes = 7

def create_model():
    # New Model architecture with additional convolutional layers
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(256, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

    # Model compilation
    optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

    return model

# %% [markdown]
# K-Fold Cross Validation & Confusion Matrix

# %%
# K-Fold Cross Validation with 80:20 split
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Define emotion labels
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

# Initialize dictionaries to store metrics for each emotion
accuracy_dict = {emotion: [] for emotion in emotion_labels}
precision_dict = {emotion: [] for emotion in emotion_labels}
recall_dict = {emotion: [] for emotion in emotion_labels}
f1_score_dict = {emotion: [] for emotion in emotion_labels}

# Get the list of filenames and corresponding classes
filenames = train_generator.filenames
classes = train_generator.classes

# Split the data into training and validation sets with an 80:20 ratio
train_files, val_files, train_classes, val_classes = train_test_split(
    filenames, classes, test_size=0.4, stratify=classes, random_state=42
)

# Loop through each fold
for fold, (train_indices, val_indices) in enumerate(skf.split(train_files, train_classes)):
    print(f"Fold {fold+1}/{skf.n_splits}")

    # Split data into training and validation sets for the current fold
    train_files_fold = [train_files[i] for i in train_indices]
    train_classes_fold = [train_classes[i] for i in train_indices]
    val_files_fold = [train_files[i] for i in val_indices]
    val_classes_fold = [train_classes[i] for i in val_indices]

    # Create dataframes for the current fold
    train_df = pd.DataFrame({'filename': train_files_fold, 'class': train_classes_fold}).astype(str)
    val_df = pd.DataFrame({'filename': val_files_fold, 'class': val_classes_fold}).astype(str)

    # Create model for each fold
    model = create_model()

    # Create data generators for the current fold
    train_generator_fold = train_datagen.flow_from_dataframe(
        train_df,
        directory=train_path,
        x_col='filename',
        y_col='class',
        target_size=target_size,
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical',
        shuffle=True
    )
    
    val_generator_fold = val_datagen.flow_from_dataframe(
        val_df,
        directory=train_path,
        x_col='filename',
        y_col='class',
        target_size=target_size,
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical',
        shuffle=False
    )

    # Train the model
    history = model.fit(
        train_generator_fold,
        epochs=10,
        validation_data=val_generator_fold,
        verbose=1
    )

    # Evaluate the model on validation set for each fold
    val_metrics = model.evaluate(
        val_generator_fold,
        verbose=0
    )
    val_loss, val_acc, val_precision, val_recall = val_metrics[0], val_metrics[1], val_metrics[2], val_metrics[3]
    
    # Calculate F1-score
    if val_precision + val_recall == 0:
        val_f1_score = 0
    else:
        val_f1_score = 2 * (val_precision * val_recall) / (val_precision + val_recall)

    # Generate confusion matrix for this fold
    y_pred = model.predict(val_generator_fold)
    y_true = val_generator_fold.classes
    conf_matrix = confusion_matrix(y_true, np.argmax(y_pred, axis=1))

    # Calculate metrics for each emotion
    for i, emotion in enumerate(emotion_labels):
        tp = conf_matrix[i, i]
        fp = np.sum(conf_matrix[:, i]) - tp
        fn = np.sum(conf_matrix[i, :]) - tp
        tn = np.sum(conf_matrix) - (tp + fp + fn)

        accuracy = (tp + tn) / (tp + tn + fp + fn) if (tp + tn + fp + fn) > 0 else 0
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        accuracy_dict[emotion].append(accuracy)
        precision_dict[emotion].append(precision)
        recall_dict[emotion].append(recall)
        f1_score_dict[emotion].append(f1_score)

    # Print metrics for each emotion
    for emotion in emotion_labels:
        print(f"Metrics for {emotion}:")
        print(f"Average Validation Accuracy: {np.mean(accuracy_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation Precision: {np.mean(precision_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation Recall: {np.mean(recall_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation F1-score: {np.mean(f1_score_dict[emotion]) * 100:.2f}%")
        print()

# Print overall average metrics
print("Overall Average Metrics:")
print(f"Average Validation Accuracy: {np.mean([np.mean(accuracy_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation Precision: {np.mean([np.mean(precision_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation Recall: {np.mean([np.mean(recall_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation F1-score: {np.mean([np.mean(f1_score_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
# Out:
# Fold 1/10
# Found 15502 validated image filenames belonging to 7 classes.
# Found 1723 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 243/243 [==============================] - 154s 591ms/step - loss: 1.8358 - accuracy: 0.2440 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.8186 - val_accuracy: 0.2513 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/10
# 243/243 [==============================] - 154s 632ms/step - loss: 1.8207 - accuracy: 0.2478 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.8117 - val_accuracy: 0.2513 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/10
# 243/243 [==============================] - 155s 638ms/step - loss: 1.8129 - accuracy: 0.2496 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7944 - val_accuracy: 0.2542 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 4/10
# 243/243 [==============================] - 142s 583ms/step - loss: 1.7964 - accuracy: 0.2557 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7892 - val_accuracy: 0.2536 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 5/10
# 243/243 [==============================] - 160s 655ms/step - loss: 1.7876 - accuracy: 0.2547 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7755 - val_accuracy: 0.2559 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 6/10
# 243/243 [==============================] - 168s 690ms/step - loss: 1.7844 - accuracy: 0.2602 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7665 - val_accuracy: 0.2612 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 7/10
# 243/243 [==============================] - 161s 661ms/step - loss: 1.7781 - accuracy: 0.2598 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7595 - val_accuracy: 0.2623 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 8/10
# 243/243 [==============================] - 143s 588ms/step - loss: 1.7716 - accuracy: 0.2632 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7450 - val_accuracy: 0.2948 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 9/10
# 243/243 [==============================] - 128s 525ms/step - loss: 1.7564 - accuracy: 0.2784 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7173 - val_accuracy: 0.3059 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 10/10
# 243/243 [==============================] - 165s 676ms/step - loss: 1.7419 - accuracy: 0.2941 - precision_1: 0.5556 - recall_1: 9.6762e-04 - val_loss: 1.6958 - val_accuracy: 0.3337 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# 27/27 [==============================] - 9s 171ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.68%
# Average Validation Precision: 36.67%
# Average Validation Recall: 13.75%
# Average Validation F1-score: 20.00%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.49%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 82.99%
# Average Validation Precision: 18.67%
# Average Validation Recall: 5.69%
# Average Validation F1-score: 8.72%
#
# Metrics for Happy:
# Average Validation Accuracy: 60.42%
# Average Validation Precision: 36.30%
# Average Validation Recall: 76.21%
# Average Validation F1-score: 49.18%
#
# Metrics for Sad:
# Average Validation Accuracy: 73.65%
# Average Validation Precision: 24.51%
# Average Validation Recall: 25.17%
# Average Validation F1-score: 24.83%
#
# Metrics for Surprise:
# Average Validation Accuracy: 81.78%
# Average Validation Precision: 37.76%
# Average Validation Recall: 12.76%
# Average Validation F1-score: 19.07%
#
# Metrics for Neutral:
# Average Validation Accuracy: 84.74%
# Average Validation Precision: 35.10%
# Average Validation Recall: 45.26%
# Average Validation F1-score: 39.54%
#
# Fold 2/10
# Found 15502 validated image filenames belonging to 7 classes.
# Found 1723 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 243/243 [==============================] - 210s 802ms/step - loss: 1.8366 - accuracy: 0.2447 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.8168 - val_accuracy: 0.2513 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/10
# 243/243 [==============================] - 139s 572ms/step - loss: 1.8213 - accuracy: 0.2476 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.8134 - val_accuracy: 0.2513 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 3/10
# 243/243 [==============================] - 148s 608ms/step - loss: 1.8199 - accuracy: 0.2487 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.8060 - val_accuracy: 0.2519 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 4/10
# 243/243 [==============================] - 172s 708ms/step - loss: 1.8069 - accuracy: 0.2527 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7870 - val_accuracy: 0.2571 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 5/10
# 243/243 [==============================] - 163s 669ms/step - loss: 1.7949 - accuracy: 0.2495 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7781 - val_accuracy: 0.2594 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 6/10
# 243/243 [==============================] - 155s 639ms/step - loss: 1.7869 - accuracy: 0.2575 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7762 - val_accuracy: 0.2565 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 7/10
# 243/243 [==============================] - 149s 614ms/step - loss: 1.7798 - accuracy: 0.2591 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7613 - val_accuracy: 0.2809 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 8/10
# 243/243 [==============================] - 155s 639ms/step - loss: 1.7681 - accuracy: 0.2669 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7461 - val_accuracy: 0.2972 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 9/10
# 243/243 [==============================] - 147s 604ms/step - loss: 1.7516 - accuracy: 0.2818 - precision_2: 0.6667 - recall_2: 1.2902e-04 - val_loss: 1.7293 - val_accuracy: 0.3024 - val_precision_2: 1.0000 - val_recall_2: 5.8038e-04
# Epoch 10/10
# 243/243 [==============================] - 159s 651ms/step - loss: 1.7370 - accuracy: 0.2915 - precision_2: 0.4688 - recall_2: 9.6762e-04 - val_loss: 1.6923 - val_accuracy: 0.3227 - val_precision_2: 0.3333 - val_recall_2: 0.0012
# 27/27 [==============================] - 7s 174ms/step
# Metrics for Angry:
# Average Validation Accuracy: 85.40%
# Average Validation Precision: 45.61%
# Average Validation Recall: 8.12%
# Average Validation F1-score: 12.39%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.49%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 84.13%
# Average Validation Precision: 14.33%
# Average Validation Recall: 3.05%
# Average Validation F1-score: 4.75%
#
# Metrics for Happy:
# Average Validation Accuracy: 62.54%
# Average Validation Precision: 37.25%
# Average Validation Recall: 71.02%
# Average Validation F1-score: 48.76%
#
# Metrics for Sad:
# Average Validation Accuracy: 75.45%
# Average Validation Precision: 26.41%
# Average Validation Recall: 23.02%
# Average Validation F1-score: 24.43%
#
# Metrics for Surprise:
# Average Validation Accuracy: 74.58%
# Average Validation Precision: 30.33%
# Average Validation Recall: 26.21%
# Average Validation F1-score: 24.06%
#
# Metrics for Neutral:
# Average Validation Accuracy: 85.06%
# Average Validation Precision: 36.06%
# Average Validation Recall: 45.41%
# Average Validation F1-score: 40.19%
#
# Fold 3/10
# Found 15502 validated image filenames belonging to 7 classes.
# Found 1723 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 243/243 [==============================] - 178s 669ms/step - loss: 1.8364 - accuracy: 0.2465 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.8173 - val_accuracy: 0.2513 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/10
# 243/243 [==============================] - 147s 605ms/step - loss: 1.8217 - accuracy: 0.2492 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.8141 - val_accuracy: 0.2513 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 3/10
# 243/243 [==============================] - 148s 609ms/step - loss: 1.8171 - accuracy: 0.2502 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.8129 - val_accuracy: 0.2513 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 4/10
# 243/243 [==============================] - 148s 605ms/step - loss: 1.8075 - accuracy: 0.2512 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7930 - val_accuracy: 0.2548 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 5/10
# 243/243 [==============================] - 122s 501ms/step - loss: 1.7984 - accuracy: 0.2504 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7842 - val_accuracy: 0.2571 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 6/10
# 243/243 [==============================] - 153s 630ms/step - loss: 1.7916 - accuracy: 0.2538 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7748 - val_accuracy: 0.2507 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 7/10
# 243/243 [==============================] - 153s 627ms/step - loss: 1.7886 - accuracy: 0.2552 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7727 - val_accuracy: 0.2571 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 8/10
# 243/243 [==============================] - 127s 521ms/step - loss: 1.7818 - accuracy: 0.2588 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7569 - val_accuracy: 0.2600 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 9/10
# 243/243 [==============================] - 127s 521ms/step - loss: 1.7762 - accuracy: 0.2616 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7475 - val_accuracy: 0.2902 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 10/10
# 243/243 [==============================] - 155s 639ms/step - loss: 1.7647 - accuracy: 0.2684 - precision_3: 1.0000 - recall_3: 6.4508e-05 - val_loss: 1.7411 - val_accuracy: 0.3140 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# 27/27 [==============================] - 6s 170ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.77%
# Average Validation Precision: 39.27%
# Average Validation Recall: 8.89%
# Average Validation F1-score: 13.25%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.49%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 82.84%
# Average Validation Precision: 16.05%
# Average Validation Recall: 6.10%
# Average Validation F1-score: 8.17%
#
# Metrics for Happy:
# Average Validation Accuracy: 63.73%
# Average Validation Precision: 37.62%
# Average Validation Recall: 66.51%
# Average Validation F1-score: 47.85%
#
# Metrics for Sad:
# Average Validation Accuracy: 76.69%
# Average Validation Precision: 29.16%
# Average Validation Recall: 23.07%
# Average Validation F1-score: 25.54%
#
# Metrics for Surprise:
# Average Validation Accuracy: 75.51%
# Average Validation Precision: 28.34%
# Average Validation Recall: 23.01%
# Average Validation F1-score: 22.62%
#
# Metrics for Neutral:
# Average Validation Accuracy: 82.67%
# Average Validation Precision: 33.34%
# Average Validation Recall: 51.21%
# Average Validation F1-score: 39.68%
#
# Fold 4/10
# Found 15502 validated image filenames belonging to 7 classes.
# Found 1723 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 243/243 [==============================] - 158s 584ms/step - loss: 1.8353 - accuracy: 0.2447 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.8165 - val_accuracy: 0.2513 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 2/10
# 243/243 [==============================] - 136s 557ms/step - loss: 1.8215 - accuracy: 0.2480 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.8139 - val_accuracy: 0.2507 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 3/10
# 243/243 [==============================] - 143s 590ms/step - loss: 1.8109 - accuracy: 0.2520 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.8007 - val_accuracy: 0.2496 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 4/10
# 243/243 [==============================] - 124s 508ms/step - loss: 1.8003 - accuracy: 0.2522 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7956 - val_accuracy: 0.2525 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 5/10
# 243/243 [==============================] - 142s 583ms/step - loss: 1.7912 - accuracy: 0.2545 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7857 - val_accuracy: 0.2542 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 6/10
# 243/243 [==============================] - 156s 639ms/step - loss: 1.7831 - accuracy: 0.2559 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7774 - val_accuracy: 0.2507 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 7/10
# 243/243 [==============================] - 155s 637ms/step - loss: 1.7769 - accuracy: 0.2629 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7705 - val_accuracy: 0.2594 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 8/10
# 243/243 [==============================] - 147s 606ms/step - loss: 1.7652 - accuracy: 0.2685 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7528 - val_accuracy: 0.2652 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 9/10
# 243/243 [==============================] - 143s 587ms/step - loss: 1.7500 - accuracy: 0.2805 - precision_4: 0.5000 - recall_4: 1.2902e-04 - val_loss: 1.7273 - val_accuracy: 0.3006 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 10/10
# 243/243 [==============================] - 152s 623ms/step - loss: 1.7357 - accuracy: 0.2950 - precision_4: 0.4359 - recall_4: 0.0011 - val_loss: 1.7149 - val_accuracy: 0.3099 - val_precision_4: 0.5000 - val_recall_4: 5.8038e-04
# 27/27 [==============================] - 6s 146ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.08%
# Average Validation Precision: 34.92%
# Average Validation Recall: 12.29%
# Average Validation F1-score: 15.48%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.43%
# Average Validation Precision: 15.88%
# Average Validation Recall: 4.78%
# Average Validation F1-score: 6.51%
#
# Metrics for Happy:
# Average Validation Accuracy: 64.73%
# Average Validation Precision: 38.06%
# Average Validation Recall: 63.05%
# Average Validation F1-score: 47.15%
#
# Metrics for Sad:
# Average Validation Accuracy: 74.83%
# Average Validation Precision: 27.78%
# Average Validation Recall: 26.02%
# Average Validation F1-score: 26.20%
#
# Metrics for Surprise:
# Average Validation Accuracy: 75.81%
# Average Validation Precision: 28.41%
# Average Validation Recall: 23.74%
# Average Validation F1-score: 23.77%
#
# Metrics for Neutral:
# Average Validation Accuracy: 83.66%
# Average Validation Precision: 34.76%
# Average Validation Recall: 47.75%
# Average Validation F1-score: 39.30%
#
# Fold 5/10
# Found 15502 validated image filenames belonging to 7 classes.
# Found 1723 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 243/243 [==============================] - 142s 524ms/step - loss: 1.8379 - accuracy: 0.2429 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.8176 - val_accuracy: 0.2513 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 2/10
# 243/243 [==============================] - 145s 594ms/step - loss: 1.8218 - accuracy: 0.2476 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.8129 - val_accuracy: 0.2513 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 3/10
# 243/243 [==============================] - 146s 598ms/step - loss: 1.8160 - accuracy: 0.2505 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.8067 - val_accuracy: 0.2513 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 4/10
# 243/243 [==============================] - 152s 623ms/step - loss: 1.8065 - accuracy: 0.2507 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7903 - val_accuracy: 0.2559 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 5/10
# 243/243 [==============================] - 128s 523ms/step - loss: 1.7926 - accuracy: 0.2523 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7828 - val_accuracy: 0.2571 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 6/10
# 243/243 [==============================] - 143s 589ms/step - loss: 1.7891 - accuracy: 0.2516 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7757 - val_accuracy: 0.2635 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 7/10
# 243/243 [==============================] - 144s 591ms/step - loss: 1.7822 - accuracy: 0.2606 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7655 - val_accuracy: 0.2618 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 8/10
# 243/243 [==============================] - 154s 634ms/step - loss: 1.7734 - accuracy: 0.2609 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7642 - val_accuracy: 0.2890 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 9/10
# 243/243 [==============================] - 154s 630ms/step - loss: 1.7630 - accuracy: 0.2738 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7390 - val_accuracy: 0.2879 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 10/10
# 243/243 [==============================] - 161s 663ms/step - loss: 1.7533 - accuracy: 0.2832 - precision_5: 0.6000 - recall_5: 1.9352e-04 - val_loss: 1.7222 - val_accuracy: 0.3186 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# 27/27 [==============================] - 6s 146ms/step
# Metrics for Angry:
# Average Validation Accuracy: 82.77%
# Average Validation Precision: 33.06%
# Average Validation Recall: 13.25%
# Average Validation F1-score: 16.49%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.47%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.70%
# Average Validation Precision: 15.91%
# Average Validation Recall: 4.15%
# Average Validation F1-score: 5.80%
#
# Metrics for Happy:
# Average Validation Accuracy: 62.28%
# Average Validation Precision: 36.88%
# Average Validation Recall: 66.47%
# Average Validation F1-score: 46.90%
#
# Metrics for Sad:
# Average Validation Accuracy: 76.16%
# Average Validation Precision: 28.26%
# Average Validation Recall: 21.89%
# Average Validation F1-score: 22.79%
#
# Metrics for Surprise:
# Average Validation Accuracy: 76.36%
# Average Validation Precision: 28.69%
# Average Validation Recall: 23.06%
# Average Validation F1-score: 23.85%
#
# Metrics for Neutral:
# Average Validation Accuracy: 84.23%
# Average Validation Precision: 35.73%
# Average Validation Recall: 46.83%
# Average Validation F1-score: 39.70%
#
# Fold 6/10
# Found 15503 validated image filenames belonging to 7 classes.
# Found 1722 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 243/243 [==============================] - 190s 712ms/step - loss: 1.8374 - accuracy: 0.2426 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.8141 - val_accuracy: 0.2515 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 2/10
# 243/243 [==============================] - 148s 606ms/step - loss: 1.8224 - accuracy: 0.2471 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.8132 - val_accuracy: 0.2515 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 3/10
# 243/243 [==============================] - 127s 519ms/step - loss: 1.8126 - accuracy: 0.2496 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7995 - val_accuracy: 0.2538 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 4/10
# 243/243 [==============================] - 150s 616ms/step - loss: 1.8028 - accuracy: 0.2508 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7829 - val_accuracy: 0.2654 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 5/10
# 243/243 [==============================] - 157s 645ms/step - loss: 1.7914 - accuracy: 0.2568 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7873 - val_accuracy: 0.2555 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 6/10
# 243/243 [==============================] - 124s 509ms/step - loss: 1.7860 - accuracy: 0.2518 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7647 - val_accuracy: 0.2654 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 7/10
# 243/243 [==============================] - 154s 631ms/step - loss: 1.7772 - accuracy: 0.2598 - precision_6: 1.0000 - recall_6: 6.4504e-05 - val_loss: 1.7520 - val_accuracy: 0.2706 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 8/10
# 243/243 [==============================] - 136s 559ms/step - loss: 1.7700 - accuracy: 0.2702 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7376 - val_accuracy: 0.2973 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 9/10
# 243/243 [==============================] - 152s 627ms/step - loss: 1.7555 - accuracy: 0.2780 - precision_6: 0.6000 - recall_6: 1.9351e-04 - val_loss: 1.7181 - val_accuracy: 0.3217 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 10/10
# 243/243 [==============================] - 155s 638ms/step - loss: 1.7423 - accuracy: 0.2913 - precision_6: 0.3600 - recall_6: 5.8053e-04 - val_loss: 1.7013 - val_accuracy: 0.3386 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# 27/27 [==============================] - 5s 152ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.27%
# Average Validation Precision: 33.69%
# Average Validation Recall: 11.53%
# Average Validation F1-score: 14.64%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.47%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.66%
# Average Validation Precision: 17.42%
# Average Validation Recall: 4.82%
# Average Validation F1-score: 6.89%
#
# Metrics for Happy:
# Average Validation Accuracy: 63.29%
# Average Validation Precision: 37.60%
# Average Validation Recall: 65.51%
# Average Validation F1-score: 47.27%
#
# Metrics for Sad:
# Average Validation Accuracy: 75.95%
# Average Validation Precision: 28.19%
# Average Validation Recall: 22.94%
# Average Validation F1-score: 23.66%
#
# Metrics for Surprise:
# Average Validation Accuracy: 75.70%
# Average Validation Precision: 28.42%
# Average Validation Recall: 25.48%
# Average Validation F1-score: 25.12%
#
# Metrics for Neutral:
# Average Validation Accuracy: 84.24%
# Average Validation Precision: 35.73%
# Average Validation Recall: 47.80%
# Average Validation F1-score: 40.18%
#
# Fold 7/10
# Found 15503 validated image filenames belonging to 7 classes.
# Found 1722 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 243/243 [==============================] - 154s 568ms/step - loss: 1.8333 - accuracy: 0.2447 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.8150 - val_accuracy: 0.2515 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 2/10
# 243/243 [==============================] - 155s 633ms/step - loss: 1.8248 - accuracy: 0.2472 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.8100 - val_accuracy: 0.2515 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 3/10
# 243/243 [==============================] - 144s 590ms/step - loss: 1.8151 - accuracy: 0.2501 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.8040 - val_accuracy: 0.2515 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 4/10
# 243/243 [==============================] - 152s 625ms/step - loss: 1.8034 - accuracy: 0.2545 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7943 - val_accuracy: 0.2590 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 5/10
# 243/243 [==============================] - 148s 608ms/step - loss: 1.7939 - accuracy: 0.2521 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7872 - val_accuracy: 0.2544 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 6/10
# 243/243 [==============================] - 152s 624ms/step - loss: 1.7847 - accuracy: 0.2567 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7786 - val_accuracy: 0.2596 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 7/10
# 243/243 [==============================] - 135s 554ms/step - loss: 1.7765 - accuracy: 0.2625 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7680 - val_accuracy: 0.2596 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 8/10
# 243/243 [==============================] - 135s 555ms/step - loss: 1.7662 - accuracy: 0.2698 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7584 - val_accuracy: 0.2677 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 9/10
# 243/243 [==============================] - 147s 603ms/step - loss: 1.7534 - accuracy: 0.2799 - precision_7: 0.8571 - recall_7: 3.8702e-04 - val_loss: 1.7322 - val_accuracy: 0.2851 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 10/10
# 243/243 [==============================] - 2587s 11s/step - loss: 1.7349 - accuracy: 0.2916 - precision_7: 0.4909 - recall_7: 0.0017 - val_loss: 1.7252 - val_accuracy: 0.2938 - val_precision_7: 0.4615 - val_recall_7: 0.0035
# 27/27 [==============================] - 6s 158ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.38%
# Average Validation Precision: 32.64%
# Average Validation Recall: 11.08%
# Average Validation F1-score: 14.36%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.47%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.40%
# Average Validation Precision: 16.82%
# Average Validation Recall: 4.83%
# Average Validation F1-score: 6.92%
#
# Metrics for Happy:
# Average Validation Accuracy: 62.29%
# Average Validation Precision: 36.92%
# Average Validation Recall: 66.25%
# Average Validation F1-score: 46.92%
#
# Metrics for Sad:
# Average Validation Accuracy: 76.67%
# Average Validation Precision: 27.91%
# Average Validation Recall: 20.43%
# Average Validation F1-score: 21.55%
#
# Metrics for Surprise:
# Average Validation Accuracy: 76.22%
# Average Validation Precision: 28.27%
# Average Validation Recall: 23.81%
# Average Validation F1-score: 24.15%
#
# Metrics for Neutral:
# Average Validation Accuracy: 83.31%
# Average Validation Precision: 34.46%
# Average Validation Recall: 49.39%
# Average Validation F1-score: 39.71%
#
# Fold 8/10
# Found 15503 validated image filenames belonging to 7 classes.
# Found 1722 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 243/243 [==============================] - 165s 612ms/step - loss: 1.8405 - accuracy: 0.2433 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.8150 - val_accuracy: 0.2515 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 2/10
# 243/243 [==============================] - 155s 635ms/step - loss: 1.8246 - accuracy: 0.2480 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.8132 - val_accuracy: 0.2515 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 3/10
# 243/243 [==============================] - 141s 576ms/step - loss: 1.8177 - accuracy: 0.2490 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.8040 - val_accuracy: 0.2515 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 4/10
# 243/243 [==============================] - 145s 593ms/step - loss: 1.8049 - accuracy: 0.2503 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7944 - val_accuracy: 0.2578 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 5/10
# 243/243 [==============================] - 150s 618ms/step - loss: 1.7938 - accuracy: 0.2535 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7852 - val_accuracy: 0.2532 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 6/10
# 243/243 [==============================] - 146s 601ms/step - loss: 1.7904 - accuracy: 0.2546 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7847 - val_accuracy: 0.2497 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 7/10
# 243/243 [==============================] - 140s 571ms/step - loss: 1.7797 - accuracy: 0.2572 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7671 - val_accuracy: 0.2828 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 8/10
# 243/243 [==============================] - 156s 641ms/step - loss: 1.7664 - accuracy: 0.2684 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7380 - val_accuracy: 0.2892 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 9/10
# 243/243 [==============================] - 146s 601ms/step - loss: 1.7491 - accuracy: 0.2807 - precision_8: 0.3077 - recall_8: 2.5801e-04 - val_loss: 1.7074 - val_accuracy: 0.3026 - val_precision_8: 1.0000 - val_recall_8: 0.0029
# Epoch 10/10
# 243/243 [==============================] - 147s 604ms/step - loss: 1.7350 - accuracy: 0.2915 - precision_8: 0.5077 - recall_8: 0.0021 - val_loss: 1.6860 - val_accuracy: 0.3159 - val_precision_8: 0.7692 - val_recall_8: 0.0058
# 27/27 [==============================] - 7s 180ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.17%
# Average Validation Precision: 31.78%
# Average Validation Recall: 11.84%
# Average Validation F1-score: 15.14%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.65%
# Average Validation Precision: 18.88%
# Average Validation Recall: 4.48%
# Average Validation F1-score: 6.53%
#
# Metrics for Happy:
# Average Validation Accuracy: 60.54%
# Average Validation Precision: 36.12%
# Average Validation Recall: 68.30%
# Average Validation F1-score: 46.63%
#
# Metrics for Sad:
# Average Validation Accuracy: 77.24%
# Average Validation Precision: 27.93%
# Average Validation Recall: 18.55%
# Average Validation F1-score: 19.98%
#
# Metrics for Surprise:
# Average Validation Accuracy: 76.74%
# Average Validation Precision: 28.49%
# Average Validation Recall: 22.39%
# Average Validation F1-score: 23.33%
#
# Metrics for Neutral:
# Average Validation Accuracy: 83.87%
# Average Validation Precision: 35.74%
# Average Validation Recall: 49.01%
# Average Validation F1-score: 40.43%
#
# Fold 9/10
# Found 15503 validated image filenames belonging to 7 classes.
# Found 1722 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 243/243 [==============================] - 165s 609ms/step - loss: 1.8359 - accuracy: 0.2445 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8139 - val_accuracy: 0.2515 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 2/10
# 243/243 [==============================] - 143s 587ms/step - loss: 1.8228 - accuracy: 0.2466 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8113 - val_accuracy: 0.2515 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 3/10
# 243/243 [==============================] - 3977s 16s/step - loss: 1.8171 - accuracy: 0.2487 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8042 - val_accuracy: 0.2520 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 4/10
# 243/243 [==============================] - 111s 457ms/step - loss: 1.8051 - accuracy: 0.2537 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7874 - val_accuracy: 0.2561 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 5/10
# 243/243 [==============================] - 112s 457ms/step - loss: 1.7935 - accuracy: 0.2550 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7730 - val_accuracy: 0.2590 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 6/10
# 243/243 [==============================] - 130s 535ms/step - loss: 1.7842 - accuracy: 0.2574 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7634 - val_accuracy: 0.2642 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 7/10
# 243/243 [==============================] - 110s 450ms/step - loss: 1.7800 - accuracy: 0.2568 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7546 - val_accuracy: 0.2822 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 8/10
# 243/243 [==============================] - 118s 487ms/step - loss: 1.7703 - accuracy: 0.2701 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7432 - val_accuracy: 0.3037 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 9/10
# 243/243 [==============================] - 120s 493ms/step - loss: 1.7569 - accuracy: 0.2770 - precision_9: 0.2500 - recall_9: 6.4504e-05 - val_loss: 1.7230 - val_accuracy: 0.2956 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 10/10
# 243/243 [==============================] - 122s 501ms/step - loss: 1.7432 - accuracy: 0.2872 - precision_9: 0.5000 - recall_9: 6.4504e-04 - val_loss: 1.7142 - val_accuracy: 0.3264 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# 27/27 [==============================] - 3671s 261ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.34%
# Average Validation Precision: 31.42%
# Average Validation Recall: 11.26%
# Average Validation F1-score: 14.66%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.87%
# Average Validation Precision: 20.95%
# Average Validation Recall: 4.11%
# Average Validation F1-score: 6.07%
#
# Metrics for Happy:
# Average Validation Accuracy: 59.79%
# Average Validation Precision: 35.79%
# Average Validation Recall: 69.85%
# Average Validation F1-score: 46.70%
#
# Metrics for Sad:
# Average Validation Accuracy: 77.74%
# Average Validation Precision: 27.96%
# Average Validation Recall: 16.90%
# Average Validation F1-score: 18.49%
#
# Metrics for Surprise:
# Average Validation Accuracy: 76.98%
# Average Validation Precision: 28.97%
# Average Validation Recall: 22.58%
# Average Validation F1-score: 23.83%
#
# Metrics for Neutral:
# Average Validation Accuracy: 83.66%
# Average Validation Precision: 35.31%
# Average Validation Recall: 49.76%
# Average Validation F1-score: 40.45%
#
# Fold 10/10
# Found 15503 validated image filenames belonging to 7 classes.
# Found 1722 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 243/243 [==============================] - 133s 494ms/step - loss: 1.8313 - accuracy: 0.2430 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.8163 - val_accuracy: 0.2509 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 2/10
# 243/243 [==============================] - 125s 513ms/step - loss: 1.8208 - accuracy: 0.2521 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.8067 - val_accuracy: 0.2509 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 3/10
# 243/243 [==============================] - 107s 441ms/step - loss: 1.8109 - accuracy: 0.2520 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7932 - val_accuracy: 0.2532 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 4/10
# 243/243 [==============================] - 116s 478ms/step - loss: 1.7983 - accuracy: 0.2555 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7845 - val_accuracy: 0.2590 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 5/10
# 243/243 [==============================] - 119s 489ms/step - loss: 1.7891 - accuracy: 0.2578 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7793 - val_accuracy: 0.2631 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 6/10
# 243/243 [==============================] - 123s 505ms/step - loss: 1.7835 - accuracy: 0.2586 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7632 - val_accuracy: 0.2636 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 7/10
# 243/243 [==============================] - 113s 467ms/step - loss: 1.7767 - accuracy: 0.2625 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7672 - val_accuracy: 0.2584 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 8/10
# 243/243 [==============================] - 121s 496ms/step - loss: 1.7663 - accuracy: 0.2710 - precision_10: 0.5000 - recall_10: 6.4504e-05 - val_loss: 1.7284 - val_accuracy: 0.2811 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 9/10
# 243/243 [==============================] - 116s 478ms/step - loss: 1.7539 - accuracy: 0.2810 - precision_10: 0.3750 - recall_10: 1.9351e-04 - val_loss: 1.7039 - val_accuracy: 0.3235 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 10/10
# 243/243 [==============================] - 118s 485ms/step - loss: 1.7351 - accuracy: 0.3007 - precision_10: 0.4000 - recall_10: 0.0017 - val_loss: 1.6805 - val_accuracy: 0.3368 - val_precision_10: 1.0000 - val_recall_10: 0.0017
# 27/27 [==============================] - 5s 134ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.62%
# Average Validation Precision: 33.67%
# Average Validation Recall: 10.43%
# Average Validation F1-score: 13.75%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.98%
# Average Validation Precision: 21.03%
# Average Validation Recall: 3.91%
# Average Validation F1-score: 5.84%
#
# Metrics for Happy:
# Average Validation Accuracy: 59.67%
# Average Validation Precision: 35.73%
# Average Validation Recall: 70.64%
# Average Validation F1-score: 46.87%
#
# Metrics for Sad:
# Average Validation Accuracy: 77.68%
# Average Validation Precision: 28.05%
# Average Validation Recall: 17.39%
# Average Validation F1-score: 19.12%
#
# Metrics for Surprise:
# Average Validation Accuracy: 76.67%
# Average Validation Precision: 28.85%
# Average Validation Recall: 23.77%
# Average Validation F1-score: 24.52%
#
# Metrics for Neutral:
# Average Validation Accuracy: 84.12%
# Average Validation Precision: 36.34%
# Average Validation Recall: 48.31%
# Average Validation F1-score: 40.38%
#
# Overall Average Metrics:
# Average Validation Accuracy: 80.60%
# Average Validation Precision: 26.24%
# Average Validation Recall: 24.92%
# Average Validation F1-score: 21.50%

# %% [markdown]
# Confusion Matrix

# %%
# Print confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Create a DataFrame for the confusion matrix
conf_df = pd.DataFrame({'TP': np.diag(conf_matrix),
                        'FP': np.sum(conf_matrix, axis=0) - np.diag(conf_matrix),
                        'FN': np.sum(conf_matrix, axis=1) - np.diag(conf_matrix),
                        'TN': np.sum(conf_matrix) - (np.diag(conf_matrix) + (np.sum(conf_matrix, axis=0) - np.diag(conf_matrix)) + (np.sum(conf_matrix, axis=1) - np.diag(conf_matrix)))})

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_df, annot=True, cmap='PuRd', fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# Confusion Matrix:
# [[  7   0   4 120  30  61  18]
#  [  0   0   1  12   7   5   1]
#  [  1   0   5 130  36  47  27]
#  [  1   0   3 336  30  50  12]
#  [  1   0   2 149  65  74   7]
#  [  3   0   2 131  39 100  15]
#  [  0   0   6  76  18  23  67]]

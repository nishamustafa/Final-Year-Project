# %% [markdown]
# Import Libraries and Packages

# %%
import os
import shutil
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import opendatasets as od
import tensorflow as tf
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %% [markdown]
# Data Extraction

# %%
# Download the dataset
dataset_url = 'https://www.kaggle.com/datasets/msambare/fer2013'
od.download(dataset_url)

# Define dataset paths
train_path = "fer2013/train"
val_path = "fer2013/test"
# Out:
# Skipping, found downloaded files in ".\fer2013" (use force=True to force download)

# %% [markdown]
# Data Pre-Processing

# %%
# Initialize data generators with data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)
val_datagen = ImageDataGenerator(rescale=1./255)

# Load training and validation data
batch_size = 64
target_size = (48, 48)
train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=target_size,
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode='categorical',
    shuffle=True
)
val_generator = val_datagen.flow_from_directory(
    val_path,
    target_size=target_size,
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode='categorical'
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# Define the number of classes
num_classes = 7

model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(256, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

    # Model compilation
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 23, 23, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 21, 21, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)         73856
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 256)         295168
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 512)               131584
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 523,015
# Trainable params: 523,015
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# CNN Algorithm

# %%
# Define the number of classes
num_classes = 7

def create_model():
    # New Model architecture with additional convolutional layers
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(256, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

    # Model compilation
    optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

    return model

# %% [markdown]
# K-Fold Cross Validation & Confusion Matrix

# %%
# K-Fold Cross Validation with 80:20 split
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Define emotion labels
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

# Initialize dictionaries to store metrics for each emotion
accuracy_dict = {emotion: [] for emotion in emotion_labels}
precision_dict = {emotion: [] for emotion in emotion_labels}
recall_dict = {emotion: [] for emotion in emotion_labels}
f1_score_dict = {emotion: [] for emotion in emotion_labels}

# Get the list of filenames and corresponding classes
filenames = train_generator.filenames
classes = train_generator.classes

# Split the data into training and validation sets with an 80:20 ratio
train_files, val_files, train_classes, val_classes = train_test_split(
    filenames, classes, test_size=0.5, stratify=classes, random_state=42
)

# Loop through each fold
for fold, (train_indices, val_indices) in enumerate(skf.split(train_files, train_classes)):
    print(f"Fold {fold+1}/{skf.n_splits}")

    # Split data into training and validation sets for the current fold
    train_files_fold = [train_files[i] for i in train_indices]
    train_classes_fold = [train_classes[i] for i in train_indices]
    val_files_fold = [train_files[i] for i in val_indices]
    val_classes_fold = [train_classes[i] for i in val_indices]

    # Create dataframes for the current fold
    train_df = pd.DataFrame({'filename': train_files_fold, 'class': train_classes_fold}).astype(str)
    val_df = pd.DataFrame({'filename': val_files_fold, 'class': val_classes_fold}).astype(str)

    # Create model for each fold
    model = create_model()

    # Create data generators for the current fold
    train_generator_fold = train_datagen.flow_from_dataframe(
        train_df,
        directory=train_path,
        x_col='filename',
        y_col='class',
        target_size=target_size,
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical',
        shuffle=True
    )
    
    val_generator_fold = val_datagen.flow_from_dataframe(
        val_df,
        directory=train_path,
        x_col='filename',
        y_col='class',
        target_size=target_size,
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical',
        shuffle=False
    )

    # Train the model
    history = model.fit(
        train_generator_fold,
        epochs=10,
        validation_data=val_generator_fold,
        verbose=1
    )

    # Evaluate the model on validation set for each fold
    val_metrics = model.evaluate(
        val_generator_fold,
        verbose=0
    )
    val_loss, val_acc, val_precision, val_recall = val_metrics[0], val_metrics[1], val_metrics[2], val_metrics[3]
    
    # Calculate F1-score
    if val_precision + val_recall == 0:
        val_f1_score = 0
    else:
        val_f1_score = 2 * (val_precision * val_recall) / (val_precision + val_recall)

    # Generate confusion matrix for this fold
    y_pred = model.predict(val_generator_fold)
    y_true = val_generator_fold.classes
    conf_matrix = confusion_matrix(y_true, np.argmax(y_pred, axis=1))

    # Calculate metrics for each emotion
    for i, emotion in enumerate(emotion_labels):
        tp = conf_matrix[i, i]
        fp = np.sum(conf_matrix[:, i]) - tp
        fn = np.sum(conf_matrix[i, :]) - tp
        tn = np.sum(conf_matrix) - (tp + fp + fn)

        accuracy = (tp + tn) / (tp + tn + fp + fn) if (tp + tn + fp + fn) > 0 else 0
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        accuracy_dict[emotion].append(accuracy)
        precision_dict[emotion].append(precision)
        recall_dict[emotion].append(recall)
        f1_score_dict[emotion].append(f1_score)

    # Print metrics for each emotion
    for emotion in emotion_labels:
        print(f"Metrics for {emotion}:")
        print(f"Average Validation Accuracy: {np.mean(accuracy_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation Precision: {np.mean(precision_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation Recall: {np.mean(recall_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation F1-score: {np.mean(f1_score_dict[emotion]) * 100:.2f}%")
        print()

# Print overall average metrics
print("Overall Average Metrics:")
print(f"Average Validation Accuracy: {np.mean([np.mean(accuracy_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation Precision: {np.mean([np.mean(precision_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation Recall: {np.mean([np.mean(recall_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation F1-score: {np.mean([np.mean(f1_score_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
# Out:
# Fold 1/10
# Found 12918 validated image filenames belonging to 7 classes.
# Found 1436 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 202/202 [==============================] - 133s 609ms/step - loss: 1.8381 - accuracy: 0.2451 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.8173 - val_accuracy: 0.2514 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/10
# 202/202 [==============================] - 123s 607ms/step - loss: 1.8238 - accuracy: 0.2473 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.8110 - val_accuracy: 0.2514 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/10
# 202/202 [==============================] - 131s 647ms/step - loss: 1.8185 - accuracy: 0.2510 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.8064 - val_accuracy: 0.2514 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 4/10
# 202/202 [==============================] - 127s 628ms/step - loss: 1.8131 - accuracy: 0.2510 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7960 - val_accuracy: 0.2563 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 5/10
# 202/202 [==============================] - 128s 631ms/step - loss: 1.8037 - accuracy: 0.2497 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7863 - val_accuracy: 0.2660 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 6/10
# 202/202 [==============================] - 152s 753ms/step - loss: 1.7923 - accuracy: 0.2545 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7715 - val_accuracy: 0.2667 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 7/10
# 202/202 [==============================] - 133s 655ms/step - loss: 1.7884 - accuracy: 0.2559 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7637 - val_accuracy: 0.2653 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 8/10
# 202/202 [==============================] - 132s 655ms/step - loss: 1.7814 - accuracy: 0.2560 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7574 - val_accuracy: 0.2702 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 9/10
# 202/202 [==============================] - 118s 582ms/step - loss: 1.7764 - accuracy: 0.2599 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7419 - val_accuracy: 0.2674 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 10/10
# 202/202 [==============================] - 135s 668ms/step - loss: 1.7651 - accuracy: 0.2757 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7244 - val_accuracy: 0.2855 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# 23/23 [==============================] - 13s 167ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.26%
# Average Validation Precision: 28.33%
# Average Validation Recall: 8.50%
# Average Validation F1-score: 13.08%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.47%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 85.31%
# Average Validation Precision: 25.00%
# Average Validation Recall: 1.46%
# Average Validation F1-score: 2.76%
#
# Metrics for Happy:
# Average Validation Accuracy: 40.25%
# Average Validation Precision: 28.11%
# Average Validation Recall: 88.37%
# Average Validation F1-score: 42.65%
#
# Metrics for Sad:
# Average Validation Accuracy: 80.36%
# Average Validation Precision: 28.00%
# Average Validation Recall: 8.43%
# Average Validation F1-score: 12.96%
#
# Metrics for Surprise:
# Average Validation Accuracy: 79.32%
# Average Validation Precision: 29.10%
# Average Validation Recall: 16.18%
# Average Validation F1-score: 20.80%
#
# Metrics for Neutral:
# Average Validation Accuracy: 89.14%
# Average Validation Precision: 55.00%
# Average Validation Recall: 6.96%
# Average Validation F1-score: 12.36%
#
# Fold 2/10
# Found 12918 validated image filenames belonging to 7 classes.
# Found 1436 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 202/202 [==============================] - 161s 702ms/step - loss: 1.8417 - accuracy: 0.2442 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.8207 - val_accuracy: 0.2514 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/10
# 202/202 [==============================] - 124s 613ms/step - loss: 1.8219 - accuracy: 0.2484 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.8158 - val_accuracy: 0.2514 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 3/10
# 202/202 [==============================] - 165s 815ms/step - loss: 1.8214 - accuracy: 0.2488 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.8129 - val_accuracy: 0.2514 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 4/10
# 202/202 [==============================] - 109s 539ms/step - loss: 1.8136 - accuracy: 0.2507 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.8045 - val_accuracy: 0.2521 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 5/10
# 202/202 [==============================] - 115s 565ms/step - loss: 1.8021 - accuracy: 0.2529 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7895 - val_accuracy: 0.2549 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 6/10
# 202/202 [==============================] - 146s 721ms/step - loss: 1.7942 - accuracy: 0.2515 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7819 - val_accuracy: 0.2549 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 7/10
# 202/202 [==============================] - 128s 631ms/step - loss: 1.7841 - accuracy: 0.2594 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7699 - val_accuracy: 0.2632 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 8/10
# 202/202 [==============================] - 132s 651ms/step - loss: 1.7780 - accuracy: 0.2616 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7547 - val_accuracy: 0.2765 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 9/10
# 202/202 [==============================] - 121s 600ms/step - loss: 1.7665 - accuracy: 0.2663 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7431 - val_accuracy: 0.2813 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 10/10
# 202/202 [==============================] - 128s 633ms/step - loss: 1.7547 - accuracy: 0.2787 - precision_2: 0.6667 - recall_2: 1.5482e-04 - val_loss: 1.7196 - val_accuracy: 0.2939 - val_precision_2: 1.0000 - val_recall_2: 6.9638e-04
# 23/23 [==============================] - 7s 207ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.51%
# Average Validation Precision: 27.80%
# Average Validation Recall: 7.27%
# Average Validation F1-score: 11.48%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.47%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 85.52%
# Average Validation Precision: 12.50%
# Average Validation Recall: 0.73%
# Average Validation F1-score: 1.38%
#
# Metrics for Happy:
# Average Validation Accuracy: 40.53%
# Average Validation Precision: 28.34%
# Average Validation Recall: 89.34%
# Average Validation F1-score: 43.03%
#
# Metrics for Sad:
# Average Validation Accuracy: 80.95%
# Average Validation Precision: 29.91%
# Average Validation Recall: 7.03%
# Average Validation F1-score: 11.26%
#
# Metrics for Surprise:
# Average Validation Accuracy: 79.67%
# Average Validation Precision: 26.91%
# Average Validation Recall: 12.64%
# Average Validation F1-score: 17.05%
#
# Metrics for Neutral:
# Average Validation Accuracy: 88.30%
# Average Validation Precision: 47.84%
# Average Validation Recall: 18.67%
# Average Validation F1-score: 23.57%
#
# Fold 3/10
# Found 12918 validated image filenames belonging to 7 classes.
# Found 1436 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 202/202 [==============================] - 145s 621ms/step - loss: 1.8371 - accuracy: 0.2439 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.8149 - val_accuracy: 0.2514 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/10
# 202/202 [==============================] - 115s 570ms/step - loss: 1.8226 - accuracy: 0.2478 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.8115 - val_accuracy: 0.2514 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 3/10
# 202/202 [==============================] - 104s 515ms/step - loss: 1.8168 - accuracy: 0.2518 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.8069 - val_accuracy: 0.2514 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 4/10
# 202/202 [==============================] - 125s 615ms/step - loss: 1.8074 - accuracy: 0.2498 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7936 - val_accuracy: 0.2611 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 5/10
# 202/202 [==============================] - 132s 652ms/step - loss: 1.7970 - accuracy: 0.2505 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7884 - val_accuracy: 0.2632 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 6/10
# 202/202 [==============================] - 128s 632ms/step - loss: 1.7914 - accuracy: 0.2521 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7785 - val_accuracy: 0.2611 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 7/10
# 202/202 [==============================] - 127s 628ms/step - loss: 1.7859 - accuracy: 0.2543 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7771 - val_accuracy: 0.2695 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 8/10
# 202/202 [==============================] - 122s 605ms/step - loss: 1.7759 - accuracy: 0.2607 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7658 - val_accuracy: 0.2597 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 9/10
# 202/202 [==============================] - 126s 622ms/step - loss: 1.7695 - accuracy: 0.2659 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7449 - val_accuracy: 0.2876 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 10/10
# 202/202 [==============================] - 126s 622ms/step - loss: 1.7547 - accuracy: 0.2823 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7377 - val_accuracy: 0.3043 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# 23/23 [==============================] - 5s 150ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.87%
# Average Validation Precision: 29.00%
# Average Validation Recall: 12.05%
# Average Validation F1-score: 16.18%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.47%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 85.24%
# Average Validation Precision: 16.38%
# Average Validation Recall: 1.63%
# Average Validation F1-score: 2.92%
#
# Metrics for Happy:
# Average Validation Accuracy: 45.15%
# Average Validation Precision: 29.43%
# Average Validation Recall: 82.92%
# Average Validation F1-score: 43.21%
#
# Metrics for Sad:
# Average Validation Accuracy: 80.45%
# Average Validation Precision: 28.53%
# Average Validation Recall: 8.05%
# Average Validation F1-score: 12.34%
#
# Metrics for Surprise:
# Average Validation Accuracy: 80.20%
# Average Validation Precision: 29.97%
# Average Validation Recall: 13.25%
# Average Validation F1-score: 18.25%
#
# Metrics for Neutral:
# Average Validation Accuracy: 85.54%
# Average Validation Precision: 40.83%
# Average Validation Recall: 27.96%
# Average Validation F1-score: 27.06%
#
# Fold 4/10
# Found 12918 validated image filenames belonging to 7 classes.
# Found 1436 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 202/202 [==============================] - 146s 635ms/step - loss: 1.8378 - accuracy: 0.2473 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.8146 - val_accuracy: 0.2514 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 2/10
# 202/202 [==============================] - 133s 659ms/step - loss: 1.8242 - accuracy: 0.2480 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.8125 - val_accuracy: 0.2514 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 3/10
# 202/202 [==============================] - 125s 618ms/step - loss: 1.8188 - accuracy: 0.2492 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.8112 - val_accuracy: 0.2514 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 4/10
# 202/202 [==============================] - 116s 571ms/step - loss: 1.8136 - accuracy: 0.2485 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.8016 - val_accuracy: 0.2514 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 5/10
# 202/202 [==============================] - 117s 578ms/step - loss: 1.8043 - accuracy: 0.2493 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7883 - val_accuracy: 0.2521 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 6/10
# 202/202 [==============================] - 119s 589ms/step - loss: 1.7932 - accuracy: 0.2521 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7742 - val_accuracy: 0.2563 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 7/10
# 202/202 [==============================] - 118s 583ms/step - loss: 1.7897 - accuracy: 0.2539 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7678 - val_accuracy: 0.2597 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 8/10
# 202/202 [==============================] - 126s 624ms/step - loss: 1.7840 - accuracy: 0.2549 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7657 - val_accuracy: 0.2625 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 9/10
# 202/202 [==============================] - 127s 624ms/step - loss: 1.7805 - accuracy: 0.2579 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7552 - val_accuracy: 0.2709 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 10/10
# 202/202 [==============================] - 113s 561ms/step - loss: 1.7724 - accuracy: 0.2626 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7423 - val_accuracy: 0.2660 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# 23/23 [==============================] - 6s 169ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.42%
# Average Validation Precision: 21.75%
# Average Validation Recall: 9.03%
# Average Validation F1-score: 12.14%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.47%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 85.38%
# Average Validation Precision: 12.28%
# Average Validation Recall: 1.22%
# Average Validation F1-score: 2.19%
#
# Metrics for Happy:
# Average Validation Accuracy: 41.90%
# Average Validation Precision: 28.65%
# Average Validation Recall: 85.73%
# Average Validation F1-score: 42.69%
#
# Metrics for Sad:
# Average Validation Accuracy: 80.61%
# Average Validation Precision: 26.40%
# Average Validation Recall: 6.84%
# Average Validation F1-score: 10.64%
#
# Metrics for Surprise:
# Average Validation Accuracy: 80.34%
# Average Validation Precision: 30.81%
# Average Validation Recall: 13.45%
# Average Validation F1-score: 18.63%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.37%
# Average Validation Precision: 30.62%
# Average Validation Recall: 20.97%
# Average Validation F1-score: 20.29%
#
# Fold 5/10
# Found 12919 validated image filenames belonging to 7 classes.
# Found 1435 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 202/202 [==============================] - 140s 614ms/step - loss: 1.8385 - accuracy: 0.2433 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.8176 - val_accuracy: 0.2516 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 2/10
# 202/202 [==============================] - 125s 617ms/step - loss: 1.8234 - accuracy: 0.2480 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.8140 - val_accuracy: 0.2516 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 3/10
# 202/202 [==============================] - 122s 601ms/step - loss: 1.8205 - accuracy: 0.2503 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.8137 - val_accuracy: 0.2516 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 4/10
# 202/202 [==============================] - 129s 636ms/step - loss: 1.8139 - accuracy: 0.2496 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.8054 - val_accuracy: 0.2544 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 5/10
# 202/202 [==============================] - 127s 625ms/step - loss: 1.8043 - accuracy: 0.2499 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7925 - val_accuracy: 0.2467 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 6/10
# 202/202 [==============================] - 118s 581ms/step - loss: 1.7959 - accuracy: 0.2516 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7918 - val_accuracy: 0.2502 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 7/10
# 202/202 [==============================] - 124s 615ms/step - loss: 1.7943 - accuracy: 0.2523 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7828 - val_accuracy: 0.2432 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 8/10
# 202/202 [==============================] - 123s 605ms/step - loss: 1.7898 - accuracy: 0.2551 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7793 - val_accuracy: 0.2488 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 9/10
# 202/202 [==============================] - 125s 618ms/step - loss: 1.7840 - accuracy: 0.2589 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7810 - val_accuracy: 0.2551 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 10/10
# 202/202 [==============================] - 120s 591ms/step - loss: 1.7806 - accuracy: 0.2566 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7688 - val_accuracy: 0.2551 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# 23/23 [==============================] - 5s 156ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.75%
# Average Validation Precision: 17.40%
# Average Validation Recall: 7.23%
# Average Validation F1-score: 9.71%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 85.46%
# Average Validation Precision: 9.83%
# Average Validation Recall: 0.98%
# Average Validation F1-score: 1.75%
#
# Metrics for Happy:
# Average Validation Accuracy: 40.49%
# Average Validation Precision: 28.15%
# Average Validation Recall: 86.04%
# Average Validation F1-score: 42.20%
#
# Metrics for Sad:
# Average Validation Accuracy: 80.93%
# Average Validation Precision: 27.78%
# Average Validation Recall: 6.04%
# Average Validation F1-score: 9.55%
#
# Metrics for Surprise:
# Average Validation Accuracy: 79.22%
# Average Validation Precision: 28.80%
# Average Validation Recall: 14.31%
# Average Validation F1-score: 18.73%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.86%
# Average Validation Precision: 31.16%
# Average Validation Recall: 16.90%
# Average Validation F1-score: 16.48%
#
# Fold 6/10
# Found 12919 validated image filenames belonging to 7 classes.
# Found 1435 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 202/202 [==============================] - 146s 646ms/step - loss: 1.8385 - accuracy: 0.2388 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.8151 - val_accuracy: 0.2509 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 2/10
# 202/202 [==============================] - 123s 606ms/step - loss: 1.8254 - accuracy: 0.2471 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.8144 - val_accuracy: 0.2509 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 3/10
# 202/202 [==============================] - 125s 621ms/step - loss: 1.8170 - accuracy: 0.2489 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.8064 - val_accuracy: 0.2509 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 4/10
# 202/202 [==============================] - 109s 537ms/step - loss: 1.8067 - accuracy: 0.2500 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7937 - val_accuracy: 0.2620 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 5/10
# 202/202 [==============================] - 101s 500ms/step - loss: 1.7980 - accuracy: 0.2525 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7878 - val_accuracy: 0.2516 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 6/10
# 202/202 [==============================] - 124s 611ms/step - loss: 1.7905 - accuracy: 0.2484 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7744 - val_accuracy: 0.2557 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 7/10
# 202/202 [==============================] - 117s 578ms/step - loss: 1.7833 - accuracy: 0.2545 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7670 - val_accuracy: 0.2613 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 8/10
# 202/202 [==============================] - 119s 586ms/step - loss: 1.7720 - accuracy: 0.2612 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7544 - val_accuracy: 0.2913 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 9/10
# 202/202 [==============================] - 131s 645ms/step - loss: 1.7598 - accuracy: 0.2750 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7299 - val_accuracy: 0.3038 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 10/10
# 202/202 [==============================] - 127s 627ms/step - loss: 1.7454 - accuracy: 0.2824 - precision_6: 0.6000 - recall_6: 6.9665e-04 - val_loss: 1.7230 - val_accuracy: 0.3178 - val_precision_6: 0.6667 - val_recall_6: 0.0014
# 23/23 [==============================] - 7s 212ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.21%
# Average Validation Precision: 18.76%
# Average Validation Recall: 12.61%
# Average Validation F1-score: 13.26%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.49%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 85.07%
# Average Validation Precision: 11.47%
# Average Validation Recall: 1.79%
# Average Validation F1-score: 2.96%
#
# Metrics for Happy:
# Average Validation Accuracy: 44.32%
# Average Validation Precision: 29.57%
# Average Validation Recall: 82.16%
# Average Validation F1-score: 42.89%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.75%
# Average Validation Precision: 27.24%
# Average Validation Recall: 9.13%
# Average Validation F1-score: 12.05%
#
# Metrics for Surprise:
# Average Validation Accuracy: 79.85%
# Average Validation Precision: 31.78%
# Average Validation Recall: 12.89%
# Average Validation F1-score: 17.33%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.72%
# Average Validation Precision: 32.24%
# Average Validation Recall: 20.79%
# Average Validation F1-score: 20.22%
#
# Fold 7/10
# Found 12919 validated image filenames belonging to 7 classes.
# Found 1435 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 202/202 [==============================] - 148s 583ms/step - loss: 1.8364 - accuracy: 0.2427 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.8186 - val_accuracy: 0.2509 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 2/10
# 202/202 [==============================] - 129s 639ms/step - loss: 1.8244 - accuracy: 0.2489 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.8128 - val_accuracy: 0.2509 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 3/10
# 202/202 [==============================] - 141s 698ms/step - loss: 1.8196 - accuracy: 0.2495 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.8077 - val_accuracy: 0.2509 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 4/10
# 202/202 [==============================] - 128s 630ms/step - loss: 1.8120 - accuracy: 0.2503 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7979 - val_accuracy: 0.2537 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 5/10
# 202/202 [==============================] - 135s 669ms/step - loss: 1.8013 - accuracy: 0.2524 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7895 - val_accuracy: 0.2655 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 6/10
# 202/202 [==============================] - 130s 639ms/step - loss: 1.7943 - accuracy: 0.2513 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7805 - val_accuracy: 0.2599 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 7/10
# 202/202 [==============================] - 133s 656ms/step - loss: 1.7893 - accuracy: 0.2530 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7724 - val_accuracy: 0.2599 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 8/10
# 202/202 [==============================] - 129s 637ms/step - loss: 1.7852 - accuracy: 0.2551 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7712 - val_accuracy: 0.2704 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 9/10
# 202/202 [==============================] - 137s 676ms/step - loss: 1.7810 - accuracy: 0.2558 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7616 - val_accuracy: 0.2697 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 10/10
# 202/202 [==============================] - 123s 608ms/step - loss: 1.7728 - accuracy: 0.2628 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7497 - val_accuracy: 0.2774 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# 23/23 [==============================] - 6s 183ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.62%
# Average Validation Precision: 16.08%
# Average Validation Recall: 10.81%
# Average Validation F1-score: 11.37%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.49%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 85.15%
# Average Validation Precision: 9.83%
# Average Validation Recall: 1.53%
# Average Validation F1-score: 2.54%
#
# Metrics for Happy:
# Average Validation Accuracy: 43.74%
# Average Validation Precision: 29.33%
# Average Validation Recall: 82.88%
# Average Validation F1-score: 42.80%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.48%
# Average Validation Precision: 26.25%
# Average Validation Recall: 9.21%
# Average Validation F1-score: 12.20%
#
# Metrics for Surprise:
# Average Validation Accuracy: 79.62%
# Average Validation Precision: 31.64%
# Average Validation Recall: 14.43%
# Average Validation F1-score: 18.67%
#
# Metrics for Neutral:
# Average Validation Accuracy: 87.04%
# Average Validation Precision: 36.21%
# Average Validation Recall: 18.09%
# Average Validation F1-score: 17.85%
#
# Fold 8/10
# Found 12919 validated image filenames belonging to 7 classes.
# Found 1435 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 202/202 [==============================] - 151s 669ms/step - loss: 1.8406 - accuracy: 0.2427 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.8188 - val_accuracy: 0.2509 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 2/10
# 202/202 [==============================] - 133s 656ms/step - loss: 1.8250 - accuracy: 0.2479 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.8123 - val_accuracy: 0.2509 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 3/10
# 202/202 [==============================] - 120s 594ms/step - loss: 1.8152 - accuracy: 0.2515 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.8059 - val_accuracy: 0.2516 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 4/10
# 202/202 [==============================] - 114s 565ms/step - loss: 1.8046 - accuracy: 0.2511 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.8018 - val_accuracy: 0.2404 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 5/10
# 202/202 [==============================] - 130s 640ms/step - loss: 1.7950 - accuracy: 0.2543 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7932 - val_accuracy: 0.2502 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 6/10
# 202/202 [==============================] - 124s 610ms/step - loss: 1.7895 - accuracy: 0.2568 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7819 - val_accuracy: 0.2467 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 7/10
# 202/202 [==============================] - 123s 608ms/step - loss: 1.7811 - accuracy: 0.2588 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7723 - val_accuracy: 0.2683 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 8/10
# 202/202 [==============================] - 123s 607ms/step - loss: 1.7718 - accuracy: 0.2680 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7556 - val_accuracy: 0.2760 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 9/10
# 202/202 [==============================] - 124s 614ms/step - loss: 1.7635 - accuracy: 0.2736 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7416 - val_accuracy: 0.3003 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 10/10
# 202/202 [==============================] - 124s 611ms/step - loss: 1.7515 - accuracy: 0.2811 - precision_8: 0.3750 - recall_8: 2.3222e-04 - val_loss: 1.7139 - val_accuracy: 0.3233 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# 23/23 [==============================] - 5s 160ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.68%
# Average Validation Precision: 18.33%
# Average Validation Recall: 11.33%
# Average Validation F1-score: 12.55%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 85.17%
# Average Validation Precision: 13.29%
# Average Validation Recall: 1.89%
# Average Validation F1-score: 3.20%
#
# Metrics for Happy:
# Average Validation Accuracy: 44.93%
# Average Validation Precision: 29.69%
# Average Validation Recall: 82.28%
# Average Validation F1-score: 43.15%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.61%
# Average Validation Precision: 27.18%
# Average Validation Recall: 9.67%
# Average Validation F1-score: 13.01%
#
# Metrics for Surprise:
# Average Validation Accuracy: 78.90%
# Average Validation Precision: 30.86%
# Average Validation Recall: 16.20%
# Average Validation F1-score: 19.70%
#
# Metrics for Neutral:
# Average Validation Accuracy: 87.30%
# Average Validation Precision: 38.08%
# Average Validation Recall: 19.21%
# Average Validation F1-score: 20.04%
#
# Fold 9/10
# Found 12919 validated image filenames belonging to 7 classes.
# Found 1435 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 202/202 [==============================] - 151s 665ms/step - loss: 1.8368 - accuracy: 0.2461 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8182 - val_accuracy: 0.2516 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 2/10
# 202/202 [==============================] - 109s 537ms/step - loss: 1.8243 - accuracy: 0.2479 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8128 - val_accuracy: 0.2516 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 3/10
# 202/202 [==============================] - 129s 638ms/step - loss: 1.8195 - accuracy: 0.2501 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8074 - val_accuracy: 0.2516 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 4/10
# 202/202 [==============================] - 97s 480ms/step - loss: 1.8122 - accuracy: 0.2498 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7989 - val_accuracy: 0.2551 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 5/10
# 202/202 [==============================] - 2552s 13s/step - loss: 1.8003 - accuracy: 0.2538 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7906 - val_accuracy: 0.2585 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 6/10
# 202/202 [==============================] - 107s 528ms/step - loss: 1.7910 - accuracy: 0.2535 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8013 - val_accuracy: 0.2571 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 7/10
# 202/202 [==============================] - 125s 617ms/step - loss: 1.7855 - accuracy: 0.2575 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7754 - val_accuracy: 0.2557 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 8/10
# 202/202 [==============================] - 129s 638ms/step - loss: 1.7824 - accuracy: 0.2576 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7789 - val_accuracy: 0.2801 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 9/10
# 202/202 [==============================] - 125s 618ms/step - loss: 1.7701 - accuracy: 0.2635 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7539 - val_accuracy: 0.2774 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 10/10
# 202/202 [==============================] - 120s 591ms/step - loss: 1.7593 - accuracy: 0.2783 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7493 - val_accuracy: 0.3052 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# 23/23 [==============================] - 6s 163ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.55%
# Average Validation Precision: 19.92%
# Average Validation Recall: 12.74%
# Average Validation F1-score: 14.23%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 84.84%
# Average Validation Precision: 13.81%
# Average Validation Recall: 2.44%
# Average Validation F1-score: 3.95%
#
# Metrics for Happy:
# Average Validation Accuracy: 46.40%
# Average Validation Precision: 30.02%
# Average Validation Recall: 80.06%
# Average Validation F1-score: 43.11%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.91%
# Average Validation Precision: 28.05%
# Average Validation Recall: 8.91%
# Average Validation F1-score: 12.15%
#
# Metrics for Surprise:
# Average Validation Accuracy: 78.61%
# Average Validation Precision: 30.62%
# Average Validation Recall: 17.49%
# Average Validation F1-score: 20.65%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.61%
# Average Validation Precision: 37.06%
# Average Validation Recall: 22.49%
# Average Validation F1-score: 21.84%
#
# Fold 10/10
# Found 12919 validated image filenames belonging to 7 classes.
# Found 1435 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 202/202 [==============================] - 143s 631ms/step - loss: 1.8338 - accuracy: 0.2483 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.8142 - val_accuracy: 0.2516 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 2/10
# 202/202 [==============================] - 130s 643ms/step - loss: 1.8215 - accuracy: 0.2482 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.8101 - val_accuracy: 0.2516 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 3/10
# 202/202 [==============================] - 118s 582ms/step - loss: 1.8155 - accuracy: 0.2520 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.8030 - val_accuracy: 0.2502 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 4/10
# 202/202 [==============================] - 128s 633ms/step - loss: 1.8048 - accuracy: 0.2521 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7967 - val_accuracy: 0.2592 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 5/10
# 202/202 [==============================] - 116s 571ms/step - loss: 1.7970 - accuracy: 0.2513 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7886 - val_accuracy: 0.2606 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 6/10
# 202/202 [==============================] - 108s 533ms/step - loss: 1.7892 - accuracy: 0.2539 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7722 - val_accuracy: 0.2599 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 7/10
# 202/202 [==============================] - 125s 614ms/step - loss: 1.7810 - accuracy: 0.2568 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7673 - val_accuracy: 0.2718 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 8/10
# 202/202 [==============================] - 121s 598ms/step - loss: 1.7711 - accuracy: 0.2656 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7549 - val_accuracy: 0.2857 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 9/10
# 202/202 [==============================] - 124s 612ms/step - loss: 1.7600 - accuracy: 0.2767 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7297 - val_accuracy: 0.3024 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 10/10
# 202/202 [==============================] - 114s 563ms/step - loss: 1.7448 - accuracy: 0.2884 - precision_10: 0.6667 - recall_10: 1.5481e-04 - val_loss: 1.7058 - val_accuracy: 0.3129 - val_precision_10: 1.0000 - val_recall_10: 0.0014
# 23/23 [==============================] - 4s 140ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.41%
# Average Validation Precision: 20.13%
# Average Validation Recall: 12.56%
# Average Validation F1-score: 14.28%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 84.89%
# Average Validation Precision: 14.43%
# Average Validation Recall: 2.29%
# Average Validation F1-score: 3.74%
#
# Metrics for Happy:
# Average Validation Accuracy: 47.19%
# Average Validation Precision: 30.22%
# Average Validation Recall: 79.34%
# Average Validation F1-score: 43.26%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.91%
# Average Validation Precision: 28.12%
# Average Validation Recall: 9.11%
# Average Validation F1-score: 12.51%
#
# Metrics for Surprise:
# Average Validation Accuracy: 78.43%
# Average Validation Precision: 29.92%
# Average Validation Recall: 17.44%
# Average Validation F1-score: 20.56%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.51%
# Average Validation Precision: 37.32%
# Average Validation Recall: 26.19%
# Average Validation F1-score: 24.42%
#
# Overall Average Metrics:
# Average Validation Accuracy: 79.83%
# Average Validation Precision: 22.88%
# Average Validation Recall: 20.99%
# Average Validation F1-score: 16.97%

# %% [markdown]
# Confusion Matrix

# %%
# Print confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Create a DataFrame for the confusion matrix
conf_df = pd.DataFrame({'TP': np.diag(conf_matrix),
                        'FP': np.sum(conf_matrix, axis=0) - np.diag(conf_matrix),
                        'FN': np.sum(conf_matrix, axis=1) - np.diag(conf_matrix),
                        'TN': np.sum(conf_matrix) - (np.diag(conf_matrix) + (np.sum(conf_matrix, axis=0) - np.diag(conf_matrix)) + (np.sum(conf_matrix, axis=1) - np.diag(conf_matrix)))})

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_df, annot=True, cmap='PuRd', fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# Confusion Matrix:
# [[ 22   0   2 109  17  33  17]
#  [  0   0   0  13   2   4   3]
#  [ 23   0   2 108  13  25  34]
#  [ 14   0   2 263  13  24  45]
#  [  7   0   3 148  27  38  25]
#  [ 20   0   0 143  18  41  19]
#  [ 14   0   1  36   4   9  94]]

# %% [markdown]
# Import Libraries and Packages

# %%
import os
import shutil
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import opendatasets as od
import tensorflow as tf
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %% [markdown]
# Data Extraction

# %%
# Download the dataset
dataset_url = 'https://www.kaggle.com/datasets/msambare/fer2013'
od.download(dataset_url)

# Define dataset paths
train_path = "fer2013/train"
val_path = "fer2013/test"
# Out:
# Skipping, found downloaded files in ".\fer2013" (use force=True to force download)

# %% [markdown]
# Data Pre-Processing

# %%
# Initialize data generators with data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)
val_datagen = ImageDataGenerator(rescale=1./255)

# Load training and validation data
batch_size = 64
target_size = (48, 48)
train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=target_size,
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode='categorical',
    shuffle=True
)
val_generator = val_datagen.flow_from_directory(
    val_path,
    target_size=target_size,
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode='categorical'
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# Define the number of classes
num_classes = 7

model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(256, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

    # Model compilation
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 23, 23, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 21, 21, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)         73856
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 256)         295168
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 512)               131584
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 523,015
# Trainable params: 523,015
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# CNN Algorithm

# %%
# Define the number of classes
num_classes = 7

def create_model():
    # New Model architecture with additional convolutional layers
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(256, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

    # Model compilation
    optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

    return model

# %% [markdown]
# K-Fold Cross Validation & Confusion Matrix

# %%
# K-Fold Cross Validation with 80:20 split
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Define emotion labels
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

# Initialize dictionaries to store metrics for each emotion
accuracy_dict = {emotion: [] for emotion in emotion_labels}
precision_dict = {emotion: [] for emotion in emotion_labels}
recall_dict = {emotion: [] for emotion in emotion_labels}
f1_score_dict = {emotion: [] for emotion in emotion_labels}

# Get the list of filenames and corresponding classes
filenames = train_generator.filenames
classes = train_generator.classes

# Split the data into training and validation sets with an 80:20 ratio
train_files, val_files, train_classes, val_classes = train_test_split(
    filenames, classes, test_size=0.3, stratify=classes, random_state=42
)

# Loop through each fold
for fold, (train_indices, val_indices) in enumerate(skf.split(train_files, train_classes)):
    print(f"Fold {fold+1}/{skf.n_splits}")

    # Split data into training and validation sets for the current fold
    train_files_fold = [train_files[i] for i in train_indices]
    train_classes_fold = [train_classes[i] for i in train_indices]
    val_files_fold = [train_files[i] for i in val_indices]
    val_classes_fold = [train_classes[i] for i in val_indices]

    # Create dataframes for the current fold
    train_df = pd.DataFrame({'filename': train_files_fold, 'class': train_classes_fold}).astype(str)
    val_df = pd.DataFrame({'filename': val_files_fold, 'class': val_classes_fold}).astype(str)

    # Create model for each fold
    model = create_model()

    # Create data generators for the current fold
    train_generator_fold = train_datagen.flow_from_dataframe(
        train_df,
        directory=train_path,
        x_col='filename',
        y_col='class',
        target_size=target_size,
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical',
        shuffle=True
    )
    
    val_generator_fold = val_datagen.flow_from_dataframe(
        val_df,
        directory=train_path,
        x_col='filename',
        y_col='class',
        target_size=target_size,
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical',
        shuffle=False
    )

    # Train the model
    history = model.fit(
        train_generator_fold,
        epochs=10,
        validation_data=val_generator_fold,
        verbose=1
    )

    # Evaluate the model on validation set for each fold
    val_metrics = model.evaluate(
        val_generator_fold,
        verbose=0
    )
    val_loss, val_acc, val_precision, val_recall = val_metrics[0], val_metrics[1], val_metrics[2], val_metrics[3]
    
    # Calculate F1-score
    if val_precision + val_recall == 0:
        val_f1_score = 0
    else:
        val_f1_score = 2 * (val_precision * val_recall) / (val_precision + val_recall)

    # Generate confusion matrix for this fold
    y_pred = model.predict(val_generator_fold)
    y_true = val_generator_fold.classes
    conf_matrix = confusion_matrix(y_true, np.argmax(y_pred, axis=1))

    # Calculate metrics for each emotion
    for i, emotion in enumerate(emotion_labels):
        tp = conf_matrix[i, i]
        fp = np.sum(conf_matrix[:, i]) - tp
        fn = np.sum(conf_matrix[i, :]) - tp
        tn = np.sum(conf_matrix) - (tp + fp + fn)

        accuracy = (tp + tn) / (tp + tn + fp + fn) if (tp + tn + fp + fn) > 0 else 0
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        accuracy_dict[emotion].append(accuracy)
        precision_dict[emotion].append(precision)
        recall_dict[emotion].append(recall)
        f1_score_dict[emotion].append(f1_score)

    # Print metrics for each emotion
    for emotion in emotion_labels:
        print(f"Metrics for {emotion}:")
        print(f"Average Validation Accuracy: {np.mean(accuracy_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation Precision: {np.mean(precision_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation Recall: {np.mean(recall_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation F1-score: {np.mean(f1_score_dict[emotion]) * 100:.2f}%")
        print()

# Print overall average metrics
print("Overall Average Metrics:")
print(f"Average Validation Accuracy: {np.mean([np.mean(accuracy_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation Precision: {np.mean([np.mean(precision_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation Recall: {np.mean([np.mean(recall_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation F1-score: {np.mean([np.mean(f1_score_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
# Out:
# Fold 1/10
# Found 18086 validated image filenames belonging to 7 classes.
# Found 2010 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 283/283 [==============================] - 182s 595ms/step - loss: 1.8356 - accuracy: 0.2408 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.8179 - val_accuracy: 0.2512 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 2/10
# 283/283 [==============================] - 166s 586ms/step - loss: 1.8212 - accuracy: 0.2485 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.8125 - val_accuracy: 0.2512 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 3/10
# 283/283 [==============================] - 180s 635ms/step - loss: 1.8163 - accuracy: 0.2505 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.8031 - val_accuracy: 0.2507 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 4/10
# 283/283 [==============================] - 173s 610ms/step - loss: 1.8024 - accuracy: 0.2546 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7873 - val_accuracy: 0.2567 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 5/10
# 283/283 [==============================] - 203s 716ms/step - loss: 1.7930 - accuracy: 0.2553 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7837 - val_accuracy: 0.2572 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 6/10
# 283/283 [==============================] - 175s 618ms/step - loss: 1.7837 - accuracy: 0.2567 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7651 - val_accuracy: 0.2597 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 7/10
# 283/283 [==============================] - 175s 619ms/step - loss: 1.7730 - accuracy: 0.2669 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - val_loss: 1.7404 - val_accuracy: 0.2920 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 8/10
# 283/283 [==============================] - 150s 531ms/step - loss: 1.7567 - accuracy: 0.2771 - precision_1: 0.6667 - recall_1: 2.2117e-04 - val_loss: 1.7156 - val_accuracy: 0.3189 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 9/10
# 283/283 [==============================] - 179s 632ms/step - loss: 1.7405 - accuracy: 0.2896 - precision_1: 0.3478 - recall_1: 8.8466e-04 - val_loss: 1.6943 - val_accuracy: 0.3303 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00
# Epoch 10/10
# 283/283 [==============================] - 184s 647ms/step - loss: 1.7242 - accuracy: 0.3033 - precision_1: 0.5469 - recall_1: 0.0074 - val_loss: 1.6606 - val_accuracy: 0.3318 - val_precision_1: 0.6250 - val_recall_1: 0.0149
# 32/32 [==============================] - 9s 138ms/step
# Metrics for Angry:
# Average Validation Accuracy: 86.02%
# Average Validation Precision: 42.86%
# Average Validation Recall: 1.07%
# Average Validation F1-score: 2.09%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.51%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 85.12%
# Average Validation Precision: 20.00%
# Average Validation Recall: 1.39%
# Average Validation F1-score: 2.61%
#
# Metrics for Happy:
# Average Validation Accuracy: 57.96%
# Average Validation Precision: 34.96%
# Average Validation Recall: 78.22%
# Average Validation F1-score: 48.32%
#
# Metrics for Sad:
# Average Validation Accuracy: 80.35%
# Average Validation Precision: 28.95%
# Average Validation Recall: 9.51%
# Average Validation F1-score: 14.32%
#
# Metrics for Surprise:
# Average Validation Accuracy: 74.73%
# Average Validation Precision: 28.17%
# Average Validation Recall: 32.15%
# Average Validation F1-score: 30.03%
#
# Metrics for Neutral:
# Average Validation Accuracy: 83.68%
# Average Validation Precision: 34.94%
# Average Validation Recall: 55.41%
# Average Validation F1-score: 42.86%
#
# Fold 2/10
# Found 18086 validated image filenames belonging to 7 classes.
# Found 2010 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 283/283 [==============================] - 174s 559ms/step - loss: 1.8348 - accuracy: 0.2400 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.8187 - val_accuracy: 0.2512 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 2/10
# 283/283 [==============================] - 193s 681ms/step - loss: 1.8213 - accuracy: 0.2463 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.8062 - val_accuracy: 0.2512 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 3/10
# 283/283 [==============================] - 161s 569ms/step - loss: 1.8058 - accuracy: 0.2497 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7873 - val_accuracy: 0.2587 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 4/10
# 283/283 [==============================] - 172s 606ms/step - loss: 1.7965 - accuracy: 0.2545 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7714 - val_accuracy: 0.2632 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 5/10
# 283/283 [==============================] - 175s 617ms/step - loss: 1.7857 - accuracy: 0.2580 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7690 - val_accuracy: 0.2677 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 6/10
# 283/283 [==============================] - 168s 594ms/step - loss: 1.7783 - accuracy: 0.2632 - precision_2: 0.0000e+00 - recall_2: 0.0000e+00 - val_loss: 1.7442 - val_accuracy: 0.2776 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 7/10
# 283/283 [==============================] - 164s 576ms/step - loss: 1.7618 - accuracy: 0.2820 - precision_2: 0.5000 - recall_2: 1.1058e-04 - val_loss: 1.7232 - val_accuracy: 0.3259 - val_precision_2: 0.0000e+00 - val_recall_2: 0.0000e+00
# Epoch 8/10
# 283/283 [==============================] - 173s 611ms/step - loss: 1.7465 - accuracy: 0.2928 - precision_2: 0.4000 - recall_2: 7.7408e-04 - val_loss: 1.6975 - val_accuracy: 0.3254 - val_precision_2: 0.5000 - val_recall_2: 4.9751e-04
# Epoch 9/10
# 283/283 [==============================] - 169s 596ms/step - loss: 1.7280 - accuracy: 0.3033 - precision_2: 0.4792 - recall_2: 0.0051 - val_loss: 1.6745 - val_accuracy: 0.3507 - val_precision_2: 0.4615 - val_recall_2: 0.0030
# Epoch 10/10
# 283/283 [==============================] - 179s 631ms/step - loss: 1.7078 - accuracy: 0.3197 - precision_2: 0.5948 - recall_2: 0.0165 - val_loss: 1.6446 - val_accuracy: 0.3617 - val_precision_2: 0.7353 - val_recall_2: 0.0249
# 32/32 [==============================] - 7s 153ms/step
# Metrics for Angry:
# Average Validation Accuracy: 85.07%
# Average Validation Precision: 38.37%
# Average Validation Recall: 7.86%
# Average Validation F1-score: 11.27%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 84.23%
# Average Validation Precision: 20.59%
# Average Validation Recall: 3.84%
# Average Validation F1-score: 6.15%
#
# Metrics for Happy:
# Average Validation Accuracy: 63.93%
# Average Validation Precision: 39.49%
# Average Validation Recall: 75.64%
# Average Validation F1-score: 51.63%
#
# Metrics for Sad:
# Average Validation Accuracy: 80.17%
# Average Validation Precision: 30.23%
# Average Validation Recall: 11.36%
# Average Validation F1-score: 16.47%
#
# Metrics for Surprise:
# Average Validation Accuracy: 74.48%
# Average Validation Precision: 28.32%
# Average Validation Recall: 33.68%
# Average Validation F1-score: 30.75%
#
# Metrics for Neutral:
# Average Validation Accuracy: 82.99%
# Average Validation Precision: 34.14%
# Average Validation Recall: 57.88%
# Average Validation F1-score: 42.90%
#
# Fold 3/10
# Found 18086 validated image filenames belonging to 7 classes.
# Found 2010 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 283/283 [==============================] - 192s 628ms/step - loss: 1.8322 - accuracy: 0.2454 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.8161 - val_accuracy: 0.2512 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/10
# 283/283 [==============================] - 172s 608ms/step - loss: 1.8204 - accuracy: 0.2500 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.8126 - val_accuracy: 0.2512 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 3/10
# 283/283 [==============================] - 166s 588ms/step - loss: 1.8126 - accuracy: 0.2517 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7991 - val_accuracy: 0.2542 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 4/10
# 283/283 [==============================] - 171s 603ms/step - loss: 1.7975 - accuracy: 0.2533 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7871 - val_accuracy: 0.2577 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 5/10
# 283/283 [==============================] - 176s 622ms/step - loss: 1.7888 - accuracy: 0.2530 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7761 - val_accuracy: 0.2607 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 6/10
# 283/283 [==============================] - 156s 552ms/step - loss: 1.7794 - accuracy: 0.2584 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7654 - val_accuracy: 0.2652 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 7/10
# 283/283 [==============================] - 166s 586ms/step - loss: 1.7686 - accuracy: 0.2667 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7417 - val_accuracy: 0.2935 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 8/10
# 283/283 [==============================] - 165s 583ms/step - loss: 1.7478 - accuracy: 0.2870 - precision_3: 0.3636 - recall_3: 2.2117e-04 - val_loss: 1.7159 - val_accuracy: 0.2920 - val_precision_3: 0.8000 - val_recall_3: 0.0020
# Epoch 9/10
# 283/283 [==============================] - 171s 604ms/step - loss: 1.7353 - accuracy: 0.2936 - precision_3: 0.5152 - recall_3: 0.0019 - val_loss: 1.6921 - val_accuracy: 0.3358 - val_precision_3: 0.6000 - val_recall_3: 0.0045
# Epoch 10/10
# 283/283 [==============================] - 154s 543ms/step - loss: 1.7157 - accuracy: 0.3061 - precision_3: 0.5319 - recall_3: 0.0069 - val_loss: 1.6618 - val_accuracy: 0.3488 - val_precision_3: 0.7692 - val_recall_3: 0.0050
# 32/32 [==============================] - 8s 197ms/step
# Metrics for Angry:
# Average Validation Accuracy: 85.09%
# Average Validation Precision: 34.88%
# Average Validation Recall: 6.67%
# Average Validation F1-score: 9.99%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.47%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.23%
# Average Validation Precision: 20.07%
# Average Validation Recall: 5.83%
# Average Validation F1-score: 8.41%
#
# Metrics for Happy:
# Average Validation Accuracy: 66.09%
# Average Validation Precision: 41.06%
# Average Validation Recall: 73.00%
# Average Validation F1-score: 52.25%
#
# Metrics for Sad:
# Average Validation Accuracy: 78.99%
# Average Validation Precision: 29.95%
# Average Validation Recall: 15.91%
# Average Validation F1-score: 19.99%
#
# Metrics for Surprise:
# Average Validation Accuracy: 72.34%
# Average Validation Precision: 27.16%
# Average Validation Recall: 37.25%
# Average Validation F1-score: 31.12%
#
# Metrics for Neutral:
# Average Validation Accuracy: 85.27%
# Average Validation Precision: 41.48%
# Average Validation Recall: 50.90%
# Average Validation F1-score: 43.46%
#
# Fold 4/10
# Found 18086 validated image filenames belonging to 7 classes.
# Found 2010 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 283/283 [==============================] - 187s 629ms/step - loss: 1.8343 - accuracy: 0.2442 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.8158 - val_accuracy: 0.2512 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 2/10
# 283/283 [==============================] - 173s 612ms/step - loss: 1.8208 - accuracy: 0.2484 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.8131 - val_accuracy: 0.2512 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 3/10
# 283/283 [==============================] - 169s 595ms/step - loss: 1.8127 - accuracy: 0.2505 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7987 - val_accuracy: 0.2498 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 4/10
# 283/283 [==============================] - 170s 601ms/step - loss: 1.8002 - accuracy: 0.2523 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7846 - val_accuracy: 0.2458 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 5/10
# 283/283 [==============================] - 166s 585ms/step - loss: 1.7912 - accuracy: 0.2570 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7801 - val_accuracy: 0.2522 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 6/10
# 283/283 [==============================] - 169s 595ms/step - loss: 1.7853 - accuracy: 0.2580 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7647 - val_accuracy: 0.2552 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 7/10
# 283/283 [==============================] - 161s 566ms/step - loss: 1.7766 - accuracy: 0.2611 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7526 - val_accuracy: 0.2796 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 8/10
# 283/283 [==============================] - 159s 562ms/step - loss: 1.7651 - accuracy: 0.2732 - precision_4: 1.0000 - recall_4: 5.5291e-05 - val_loss: 1.7335 - val_accuracy: 0.3055 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 9/10
# 283/283 [==============================] - 167s 589ms/step - loss: 1.7507 - accuracy: 0.2872 - precision_4: 0.4000 - recall_4: 3.3175e-04 - val_loss: 1.7120 - val_accuracy: 0.3303 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 10/10
# 283/283 [==============================] - 175s 618ms/step - loss: 1.7341 - accuracy: 0.2993 - precision_4: 0.4828 - recall_4: 0.0023 - val_loss: 1.6845 - val_accuracy: 0.3204 - val_precision_4: 0.6102 - val_recall_4: 0.0179
# 32/32 [==============================] - 7s 169ms/step
# Metrics for Angry:
# Average Validation Accuracy: 85.25%
# Average Validation Precision: 35.09%
# Average Validation Recall: 5.90%
# Average Validation F1-score: 9.12%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.47%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.81%
# Average Validation Precision: 22.56%
# Average Validation Recall: 4.63%
# Average Validation F1-score: 6.82%
#
# Metrics for Happy:
# Average Validation Accuracy: 60.98%
# Average Validation Precision: 38.36%
# Average Validation Recall: 77.03%
# Average Validation F1-score: 50.48%
#
# Metrics for Sad:
# Average Validation Accuracy: 79.76%
# Average Validation Precision: 33.29%
# Average Validation Recall: 14.73%
# Average Validation F1-score: 19.44%
#
# Metrics for Surprise:
# Average Validation Accuracy: 73.41%
# Average Validation Precision: 27.18%
# Average Validation Recall: 33.78%
# Average Validation F1-score: 29.63%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.46%
# Average Validation Precision: 46.11%
# Average Validation Recall: 45.27%
# Average Validation F1-score: 42.23%
#
# Fold 5/10
# Found 18086 validated image filenames belonging to 7 classes.
# Found 2010 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 283/283 [==============================] - 184s 606ms/step - loss: 1.8318 - accuracy: 0.2422 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.8155 - val_accuracy: 0.2512 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 2/10
# 283/283 [==============================] - 155s 547ms/step - loss: 1.8181 - accuracy: 0.2481 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.8028 - val_accuracy: 0.2512 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 3/10
# 283/283 [==============================] - 163s 576ms/step - loss: 1.8034 - accuracy: 0.2511 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7899 - val_accuracy: 0.2637 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 4/10
# 283/283 [==============================] - 176s 622ms/step - loss: 1.7914 - accuracy: 0.2552 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7827 - val_accuracy: 0.2637 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 5/10
# 283/283 [==============================] - 175s 617ms/step - loss: 1.7812 - accuracy: 0.2611 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7671 - val_accuracy: 0.2637 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 6/10
# 283/283 [==============================] - 182s 640ms/step - loss: 1.7696 - accuracy: 0.2679 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7483 - val_accuracy: 0.2811 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 7/10
# 283/283 [==============================] - 195s 687ms/step - loss: 1.7529 - accuracy: 0.2831 - precision_5: 0.3333 - recall_5: 1.6587e-04 - val_loss: 1.7178 - val_accuracy: 0.3090 - val_precision_5: 0.4000 - val_recall_5: 9.9502e-04
# Epoch 8/10
# 283/283 [==============================] - 181s 637ms/step - loss: 1.7318 - accuracy: 0.3017 - precision_5: 0.6071 - recall_5: 0.0038 - val_loss: 1.6994 - val_accuracy: 0.3438 - val_precision_5: 0.1667 - val_recall_5: 4.9751e-04
# Epoch 9/10
# 283/283 [==============================] - 171s 601ms/step - loss: 1.7110 - accuracy: 0.3127 - precision_5: 0.5656 - recall_5: 0.0122 - val_loss: 1.6772 - val_accuracy: 0.3244 - val_precision_5: 0.6729 - val_recall_5: 0.0358
# Epoch 10/10
# 283/283 [==============================] - 191s 674ms/step - loss: 1.6972 - accuracy: 0.3227 - precision_5: 0.5522 - recall_5: 0.0213 - val_loss: 1.6521 - val_accuracy: 0.3632 - val_precision_5: 0.7000 - val_recall_5: 0.0174
# 32/32 [==============================] - 7s 158ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.64%
# Average Validation Precision: 33.80%
# Average Validation Recall: 8.52%
# Average Validation F1-score: 11.87%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.47%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 84.06%
# Average Validation Precision: 22.84%
# Average Validation Recall: 4.12%
# Average Validation F1-score: 6.22%
#
# Metrics for Happy:
# Average Validation Accuracy: 63.57%
# Average Validation Precision: 40.41%
# Average Validation Recall: 74.57%
# Average Validation F1-score: 51.49%
#
# Metrics for Sad:
# Average Validation Accuracy: 78.51%
# Average Validation Precision: 32.18%
# Average Validation Recall: 18.40%
# Average Validation F1-score: 21.58%
#
# Metrics for Surprise:
# Average Validation Accuracy: 72.89%
# Average Validation Precision: 26.96%
# Average Validation Recall: 35.07%
# Average Validation F1-score: 30.04%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.91%
# Average Validation Precision: 46.63%
# Average Validation Recall: 44.59%
# Average Validation F1-score: 42.79%
#
# Fold 6/10
# Found 18086 validated image filenames belonging to 7 classes.
# Found 2010 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 283/283 [==============================] - 202s 651ms/step - loss: 1.8347 - accuracy: 0.2485 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.8149 - val_accuracy: 0.2512 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 2/10
# 283/283 [==============================] - 162s 571ms/step - loss: 1.8222 - accuracy: 0.2486 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.8138 - val_accuracy: 0.2512 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 3/10
# 283/283 [==============================] - 177s 624ms/step - loss: 1.8120 - accuracy: 0.2522 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7996 - val_accuracy: 0.2527 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 4/10
# 283/283 [==============================] - 169s 597ms/step - loss: 1.7969 - accuracy: 0.2547 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7844 - val_accuracy: 0.2537 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 5/10
# 283/283 [==============================] - 165s 584ms/step - loss: 1.7895 - accuracy: 0.2568 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7784 - val_accuracy: 0.2637 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 6/10
# 283/283 [==============================] - 178s 626ms/step - loss: 1.7810 - accuracy: 0.2572 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7641 - val_accuracy: 0.2637 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 7/10
# 283/283 [==============================] - 172s 606ms/step - loss: 1.7696 - accuracy: 0.2665 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7480 - val_accuracy: 0.2871 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 8/10
# 283/283 [==============================] - 175s 616ms/step - loss: 1.7534 - accuracy: 0.2810 - precision_6: 0.3333 - recall_6: 1.1058e-04 - val_loss: 1.7186 - val_accuracy: 0.2985 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 9/10
# 283/283 [==============================] - 166s 584ms/step - loss: 1.7355 - accuracy: 0.2930 - precision_6: 0.5556 - recall_6: 0.0014 - val_loss: 1.6885 - val_accuracy: 0.3393 - val_precision_6: 1.0000 - val_recall_6: 0.0015
# Epoch 10/10
# 283/283 [==============================] - 171s 603ms/step - loss: 1.7149 - accuracy: 0.3089 - precision_6: 0.5733 - recall_6: 0.0071 - val_loss: 1.6676 - val_accuracy: 0.3587 - val_precision_6: 0.5610 - val_recall_6: 0.0114
# 32/32 [==============================] - 7s 163ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.67%
# Average Validation Precision: 33.49%
# Average Validation Recall: 8.47%
# Average Validation F1-score: 12.07%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.47%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 84.25%
# Average Validation Precision: 23.58%
# Average Validation Recall: 3.78%
# Average Validation F1-score: 5.83%
#
# Metrics for Happy:
# Average Validation Accuracy: 64.65%
# Average Validation Precision: 40.89%
# Average Validation Recall: 72.51%
# Average Validation F1-score: 51.42%
#
# Metrics for Sad:
# Average Validation Accuracy: 78.26%
# Average Validation Precision: 31.94%
# Average Validation Recall: 19.69%
# Average Validation F1-score: 22.70%
#
# Metrics for Surprise:
# Average Validation Accuracy: 72.88%
# Average Validation Precision: 27.26%
# Average Validation Recall: 36.18%
# Average Validation F1-score: 30.71%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.31%
# Average Validation Precision: 44.86%
# Average Validation Recall: 48.12%
# Average Validation F1-score: 43.42%
#
# Fold 7/10
# Found 18087 validated image filenames belonging to 7 classes.
# Found 2009 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 283/283 [==============================] - 188s 599ms/step - loss: 1.8330 - accuracy: 0.2433 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.8145 - val_accuracy: 0.2514 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 2/10
# 283/283 [==============================] - 2606s 9s/step - loss: 1.8215 - accuracy: 0.2481 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.8070 - val_accuracy: 0.2514 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 3/10
# 283/283 [==============================] - 156s 550ms/step - loss: 1.8071 - accuracy: 0.2510 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7896 - val_accuracy: 0.2549 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 4/10
# 283/283 [==============================] - 169s 595ms/step - loss: 1.7957 - accuracy: 0.2535 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7883 - val_accuracy: 0.2504 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 5/10
# 283/283 [==============================] - 154s 545ms/step - loss: 1.7868 - accuracy: 0.2544 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7793 - val_accuracy: 0.2633 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 6/10
# 283/283 [==============================] - 163s 577ms/step - loss: 1.7757 - accuracy: 0.2642 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7505 - val_accuracy: 0.2763 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 7/10
# 283/283 [==============================] - 162s 573ms/step - loss: 1.7607 - accuracy: 0.2765 - precision_7: 0.5000 - recall_7: 5.5288e-05 - val_loss: 1.7261 - val_accuracy: 0.3001 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 8/10
# 283/283 [==============================] - 167s 590ms/step - loss: 1.7405 - accuracy: 0.2887 - precision_7: 0.6429 - recall_7: 0.0015 - val_loss: 1.6938 - val_accuracy: 0.3176 - val_precision_7: 0.6154 - val_recall_7: 0.0040
# Epoch 9/10
# 283/283 [==============================] - 177s 623ms/step - loss: 1.7182 - accuracy: 0.3028 - precision_7: 0.5656 - recall_7: 0.0076 - val_loss: 1.6867 - val_accuracy: 0.3255 - val_precision_7: 0.5588 - val_recall_7: 0.0095
# Epoch 10/10
# 283/283 [==============================] - 177s 625ms/step - loss: 1.7060 - accuracy: 0.3119 - precision_7: 0.5888 - recall_7: 0.0180 - val_loss: 1.6327 - val_accuracy: 0.3614 - val_precision_7: 0.7184 - val_recall_7: 0.0368
# 32/32 [==============================] - 8s 173ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.69%
# Average Validation Precision: 34.05%
# Average Validation Recall: 9.15%
# Average Validation F1-score: 13.14%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.47%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 84.28%
# Average Validation Precision: 23.49%
# Average Validation Recall: 3.79%
# Average Validation F1-score: 5.94%
#
# Metrics for Happy:
# Average Validation Accuracy: 64.35%
# Average Validation Precision: 40.56%
# Average Validation Recall: 73.95%
# Average Validation F1-score: 51.58%
#
# Metrics for Sad:
# Average Validation Accuracy: 78.14%
# Average Validation Precision: 31.66%
# Average Validation Recall: 20.17%
# Average Validation F1-score: 23.18%
#
# Metrics for Surprise:
# Average Validation Accuracy: 73.86%
# Average Validation Precision: 27.84%
# Average Validation Recall: 33.42%
# Average Validation F1-score: 29.45%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.09%
# Average Validation Precision: 43.79%
# Average Validation Recall: 49.23%
# Average Validation F1-score: 43.61%
#
# Fold 8/10
# Found 18087 validated image filenames belonging to 7 classes.
# Found 2009 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 283/283 [==============================] - 183s 587ms/step - loss: 1.8335 - accuracy: 0.2451 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.8150 - val_accuracy: 0.2514 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 2/10
# 283/283 [==============================] - 163s 576ms/step - loss: 1.8215 - accuracy: 0.2463 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.8110 - val_accuracy: 0.2514 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 3/10
# 283/283 [==============================] - 170s 601ms/step - loss: 1.8122 - accuracy: 0.2500 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7989 - val_accuracy: 0.2593 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 4/10
# 283/283 [==============================] - 4003s 14s/step - loss: 1.7991 - accuracy: 0.2500 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7815 - val_accuracy: 0.2573 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 5/10
# 283/283 [==============================] - 142s 501ms/step - loss: 1.7908 - accuracy: 0.2561 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7726 - val_accuracy: 0.2588 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 6/10
# 283/283 [==============================] - 147s 517ms/step - loss: 1.7821 - accuracy: 0.2586 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7677 - val_accuracy: 0.2832 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 7/10
# 283/283 [==============================] - 124s 436ms/step - loss: 1.7718 - accuracy: 0.2618 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7491 - val_accuracy: 0.2653 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 8/10
# 283/283 [==============================] - 143s 505ms/step - loss: 1.7607 - accuracy: 0.2708 - precision_8: 1.0000 - recall_8: 5.5288e-05 - val_loss: 1.7254 - val_accuracy: 0.2837 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 9/10
# 283/283 [==============================] - 143s 506ms/step - loss: 1.7422 - accuracy: 0.2890 - precision_8: 0.5417 - recall_8: 7.1875e-04 - val_loss: 1.7106 - val_accuracy: 0.3186 - val_precision_8: 0.3333 - val_recall_8: 4.9776e-04
# Epoch 10/10
# 283/283 [==============================] - 3794s 13s/step - loss: 1.7238 - accuracy: 0.3019 - precision_8: 0.5405 - recall_8: 0.0033 - val_loss: 1.7050 - val_accuracy: 0.3166 - val_precision_8: 0.5750 - val_recall_8: 0.0114
# 32/32 [==============================] - 7s 170ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.56%
# Average Validation Precision: 32.75%
# Average Validation Recall: 8.99%
# Average Validation F1-score: 12.97%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.55%
# Average Validation Precision: 22.63%
# Average Validation Recall: 4.89%
# Average Validation F1-score: 6.98%
#
# Metrics for Happy:
# Average Validation Accuracy: 65.26%
# Average Validation Precision: 41.08%
# Average Validation Recall: 71.61%
# Average Validation F1-score: 51.31%
#
# Metrics for Sad:
# Average Validation Accuracy: 78.18%
# Average Validation Precision: 31.78%
# Average Validation Recall: 20.53%
# Average Validation F1-score: 23.66%
#
# Metrics for Surprise:
# Average Validation Accuracy: 74.36%
# Average Validation Precision: 27.82%
# Average Validation Recall: 31.68%
# Average Validation F1-score: 28.63%
#
# Metrics for Neutral:
# Average Validation Accuracy: 84.67%
# Average Validation Precision: 41.55%
# Average Validation Recall: 51.69%
# Average Validation F1-score: 42.86%
#
# Fold 9/10
# Found 18087 validated image filenames belonging to 7 classes.
# Found 2009 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 283/283 [==============================] - 146s 470ms/step - loss: 1.8320 - accuracy: 0.2468 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8135 - val_accuracy: 0.2514 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 2/10
# 283/283 [==============================] - 135s 475ms/step - loss: 1.8199 - accuracy: 0.2479 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8089 - val_accuracy: 0.2514 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 3/10
# 283/283 [==============================] - 130s 459ms/step - loss: 1.8104 - accuracy: 0.2511 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7950 - val_accuracy: 0.2549 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 4/10
# 283/283 [==============================] - 135s 476ms/step - loss: 1.7960 - accuracy: 0.2542 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7816 - val_accuracy: 0.2588 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 5/10
# 283/283 [==============================] - 140s 493ms/step - loss: 1.7883 - accuracy: 0.2554 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7747 - val_accuracy: 0.2598 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 6/10
# 283/283 [==============================] - 131s 461ms/step - loss: 1.7782 - accuracy: 0.2618 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7552 - val_accuracy: 0.2678 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 7/10
# 283/283 [==============================] - 134s 474ms/step - loss: 1.7615 - accuracy: 0.2727 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7306 - val_accuracy: 0.3021 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 8/10
# 283/283 [==============================] - 139s 489ms/step - loss: 1.7430 - accuracy: 0.2863 - precision_9: 0.3846 - recall_9: 2.7644e-04 - val_loss: 1.7007 - val_accuracy: 0.3240 - val_precision_9: 1.0000 - val_recall_9: 4.9776e-04
# Epoch 9/10
# 283/283 [==============================] - 120s 424ms/step - loss: 1.7274 - accuracy: 0.2958 - precision_9: 0.4500 - recall_9: 0.0030 - val_loss: 1.6712 - val_accuracy: 0.3260 - val_precision_9: 0.5000 - val_recall_9: 0.0035
# Epoch 10/10
# 283/283 [==============================] - 106s 373ms/step - loss: 1.7069 - accuracy: 0.3137 - precision_9: 0.5439 - recall_9: 0.0123 - val_loss: 1.6499 - val_accuracy: 0.3574 - val_precision_9: 0.6667 - val_recall_9: 0.0090
# 32/32 [==============================] - 5s 116ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.34%
# Average Validation Precision: 32.42%
# Average Validation Recall: 10.01%
# Average Validation F1-score: 14.04%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.44%
# Average Validation Precision: 22.97%
# Average Validation Recall: 5.66%
# Average Validation F1-score: 8.01%
#
# Metrics for Happy:
# Average Validation Accuracy: 65.40%
# Average Validation Precision: 41.02%
# Average Validation Recall: 71.55%
# Average Validation F1-score: 51.35%
#
# Metrics for Sad:
# Average Validation Accuracy: 78.16%
# Average Validation Precision: 31.22%
# Average Validation Recall: 20.01%
# Average Validation F1-score: 23.24%
#
# Metrics for Surprise:
# Average Validation Accuracy: 74.43%
# Average Validation Precision: 28.17%
# Average Validation Recall: 32.60%
# Average Validation F1-score: 29.33%
#
# Metrics for Neutral:
# Average Validation Accuracy: 85.09%
# Average Validation Precision: 42.15%
# Average Validation Recall: 50.15%
# Average Validation F1-score: 42.76%
#
# Fold 10/10
# Found 18087 validated image filenames belonging to 7 classes.
# Found 2009 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 283/283 [==============================] - 118s 391ms/step - loss: 1.8321 - accuracy: 0.2449 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.8154 - val_accuracy: 0.2514 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 2/10
# 283/283 [==============================] - 103s 363ms/step - loss: 1.8194 - accuracy: 0.2482 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.8100 - val_accuracy: 0.2514 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 3/10
# 283/283 [==============================] - 105s 371ms/step - loss: 1.8079 - accuracy: 0.2516 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7966 - val_accuracy: 0.2628 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 4/10
# 283/283 [==============================] - 109s 386ms/step - loss: 1.7960 - accuracy: 0.2528 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7773 - val_accuracy: 0.2623 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 5/10
# 283/283 [==============================] - 106s 374ms/step - loss: 1.7858 - accuracy: 0.2565 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7639 - val_accuracy: 0.2723 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 6/10
# 283/283 [==============================] - 108s 379ms/step - loss: 1.7744 - accuracy: 0.2607 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7457 - val_accuracy: 0.2922 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 7/10
# 283/283 [==============================] - 78s 274ms/step - loss: 1.7561 - accuracy: 0.2777 - precision_10: 0.3333 - recall_10: 5.5288e-05 - val_loss: 1.7210 - val_accuracy: 0.3305 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 8/10
# 283/283 [==============================] - 68s 240ms/step - loss: 1.7387 - accuracy: 0.2874 - precision_10: 0.3214 - recall_10: 4.9759e-04 - val_loss: 1.6954 - val_accuracy: 0.3280 - val_precision_10: 0.6522 - val_recall_10: 0.0075
# Epoch 9/10
# 283/283 [==============================] - 74s 260ms/step - loss: 1.7198 - accuracy: 0.3065 - precision_10: 0.5678 - recall_10: 0.0062 - val_loss: 1.6503 - val_accuracy: 0.3589 - val_precision_10: 0.6957 - val_recall_10: 0.0239
# Epoch 10/10
# 283/283 [==============================] - 75s 265ms/step - loss: 1.7037 - accuracy: 0.3127 - precision_10: 0.5416 - recall_10: 0.0155 - val_loss: 1.6542 - val_accuracy: 0.3654 - val_precision_10: 0.6304 - val_recall_10: 0.0289
# 32/32 [==============================] - 3s 89ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.43%
# Average Validation Precision: 33.48%
# Average Validation Recall: 10.76%
# Average Validation F1-score: 15.12%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.11%
# Average Validation Precision: 22.53%
# Average Validation Recall: 6.24%
# Average Validation F1-score: 8.63%
#
# Metrics for Happy:
# Average Validation Accuracy: 66.02%
# Average Validation Precision: 41.46%
# Average Validation Recall: 70.91%
# Average Validation F1-score: 51.57%
#
# Metrics for Sad:
# Average Validation Accuracy: 78.20%
# Average Validation Precision: 31.09%
# Average Validation Recall: 19.80%
# Average Validation F1-score: 23.15%
#
# Metrics for Surprise:
# Average Validation Accuracy: 74.90%
# Average Validation Precision: 28.90%
# Average Validation Recall: 32.30%
# Average Validation F1-score: 29.62%
#
# Metrics for Neutral:
# Average Validation Accuracy: 84.56%
# Average Validation Precision: 41.12%
# Average Validation Recall: 52.39%
# Average Validation F1-score: 42.91%
#
# Overall Average Metrics:
# Average Validation Accuracy: 81.39%
# Average Validation Precision: 28.37%
# Average Validation Recall: 27.49%
# Average Validation F1-score: 24.43%

# %% [markdown]
# Confusion Matrix

# %%
# Print confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Create a DataFrame for the confusion matrix
conf_df = pd.DataFrame({'TP': np.diag(conf_matrix),
                        'FP': np.sum(conf_matrix, axis=0) - np.diag(conf_matrix),
                        'FN': np.sum(conf_matrix, axis=1) - np.diag(conf_matrix),
                        'TN': np.sum(conf_matrix) - (np.diag(conf_matrix) + (np.sum(conf_matrix, axis=0) - np.diag(conf_matrix)) + (np.sum(conf_matrix, axis=1) - np.diag(conf_matrix)))})

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_df, annot=True, cmap='PuRd', fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# Confusion Matrix:
# [[ 49   0  30  71  32  44  54]
#  [  3   0   2   8   5   3   9]
#  [ 15   0  33  75  27  37 100]
#  [ 19   0  23 329  34  23  77]
#  [ 16   0  33 130  62  61  45]
#  [ 11   0  37  92  39 100  59]
#  [  1   0  20  18   8  14 161]]

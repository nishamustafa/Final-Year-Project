# %% [markdown]
# Import Libraries and Packages

# %%
import os
import shutil
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import opendatasets as od
import tensorflow as tf
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %% [markdown]
# Data Extraction

# %%
# Download the dataset
dataset_url = 'https://www.kaggle.com/datasets/msambare/fer2013'
od.download(dataset_url)

# Define dataset paths
train_path = "fer2013/train"
val_path = "fer2013/test"
# Out:
# Skipping, found downloaded files in ".\fer2013" (use force=True to force download)

# %% [markdown]
# Data Pre-Processing

# %%
# Initialize data generators with data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)
val_datagen = ImageDataGenerator(rescale=1./255)

# Load training and validation data
batch_size = 64
target_size = (48, 48)
train_generator = train_datagen.flow_from_directory(
    train_path,
    target_size=target_size,
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode='categorical',
    shuffle=True
)
val_generator = val_datagen.flow_from_directory(
    val_path,
    target_size=target_size,
    batch_size=batch_size,
    color_mode="grayscale",
    class_mode='categorical'
)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# Define the number of classes
num_classes = 7

model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(256, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

    # Model compilation
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 46, 46, 32)        320
#
#  max_pooling2d_8 (MaxPooling  (None, 23, 23, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 21, 21, 64)        18496
#
#  max_pooling2d_9 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 128)         73856
#
#  max_pooling2d_10 (MaxPoolin  (None, 4, 4, 128)        0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 2, 2, 256)         295168
#
#  max_pooling2d_11 (MaxPoolin  (None, 1, 1, 256)        0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 512)               131584
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 523,015
# Trainable params: 523,015
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# CNN Algorithm

# %%
# Define the number of classes
num_classes = 7

def create_model():
    # New Model architecture with additional convolutional layers
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(48, 48, 1)),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Conv2D(256, (3, 3), activation='relu'),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

    # Model compilation
    optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

    return model

# %% [markdown]
# K-Fold Cross Validation & Confusion Matrix

# %%
# K-Fold Cross Validation with 80:20 split
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Define emotion labels
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

# Initialize dictionaries to store metrics for each emotion
accuracy_dict = {emotion: [] for emotion in emotion_labels}
precision_dict = {emotion: [] for emotion in emotion_labels}
recall_dict = {emotion: [] for emotion in emotion_labels}
f1_score_dict = {emotion: [] for emotion in emotion_labels}

# Get the list of filenames and corresponding classes
filenames = train_generator.filenames
classes = train_generator.classes

# Split the data into training and validation sets with an 80:20 ratio
train_files, val_files, train_classes, val_classes = train_test_split(
    filenames, classes, test_size=0.2, stratify=classes, random_state=42
)

# Loop through each fold
for fold, (train_indices, val_indices) in enumerate(skf.split(train_files, train_classes)):
    print(f"Fold {fold+1}/{skf.n_splits}")

    # Split data into training and validation sets for the current fold
    train_files_fold = [train_files[i] for i in train_indices]
    train_classes_fold = [train_classes[i] for i in train_indices]
    val_files_fold = [train_files[i] for i in val_indices]
    val_classes_fold = [train_classes[i] for i in val_indices]

    # Create dataframes for the current fold
    train_df = pd.DataFrame({'filename': train_files_fold, 'class': train_classes_fold}).astype(str)
    val_df = pd.DataFrame({'filename': val_files_fold, 'class': val_classes_fold}).astype(str)

    # Create model for each fold
    model = create_model()

    # Create data generators for the current fold
    train_generator_fold = train_datagen.flow_from_dataframe(
        train_df,
        directory=train_path,
        x_col='filename',
        y_col='class',
        target_size=target_size,
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical',
        shuffle=True
    )
    
    val_generator_fold = val_datagen.flow_from_dataframe(
        val_df,
        directory=train_path,
        x_col='filename',
        y_col='class',
        target_size=target_size,
        batch_size=batch_size,
        color_mode="grayscale",
        class_mode='categorical',
        shuffle=False
    )

    # Train the model
    history = model.fit(
        train_generator_fold,
        epochs=10,
        validation_data=val_generator_fold,
        verbose=1
    )

    # Evaluate the model on validation set for each fold
    val_metrics = model.evaluate(
        val_generator_fold,
        verbose=0
    )
    val_loss, val_acc, val_precision, val_recall = val_metrics[0], val_metrics[1], val_metrics[2], val_metrics[3]
    
    # Calculate F1-score
    if val_precision + val_recall == 0:
        val_f1_score = 0
    else:
        val_f1_score = 2 * (val_precision * val_recall) / (val_precision + val_recall)

    # Generate confusion matrix for this fold
    y_pred = model.predict(val_generator_fold)
    y_true = val_generator_fold.classes
    conf_matrix = confusion_matrix(y_true, np.argmax(y_pred, axis=1))

    # Calculate metrics for each emotion
    for i, emotion in enumerate(emotion_labels):
        tp = conf_matrix[i, i]
        fp = np.sum(conf_matrix[:, i]) - tp
        fn = np.sum(conf_matrix[i, :]) - tp
        tn = np.sum(conf_matrix) - (tp + fp + fn)

        accuracy = (tp + tn) / (tp + tn + fp + fn) if (tp + tn + fp + fn) > 0 else 0
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        accuracy_dict[emotion].append(accuracy)
        precision_dict[emotion].append(precision)
        recall_dict[emotion].append(recall)
        f1_score_dict[emotion].append(f1_score)

    # Print metrics for each emotion
    for emotion in emotion_labels:
        print(f"Metrics for {emotion}:")
        print(f"Average Validation Accuracy: {np.mean(accuracy_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation Precision: {np.mean(precision_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation Recall: {np.mean(recall_dict[emotion]) * 100:.2f}%")
        print(f"Average Validation F1-score: {np.mean(f1_score_dict[emotion]) * 100:.2f}%")
        print()

# Print overall average metrics
print("Overall Average Metrics:")
print(f"Average Validation Accuracy: {np.mean([np.mean(accuracy_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation Precision: {np.mean([np.mean(precision_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation Recall: {np.mean([np.mean(recall_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
print(f"Average Validation F1-score: {np.mean([np.mean(f1_score_dict[emotion]) for emotion in emotion_labels]) * 100:.2f}%")
# Out:
# Fold 1/10
# Found 20670 validated image filenames belonging to 7 classes.
# Found 2297 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 323/323 [==============================] - 99s 293ms/step - loss: 1.8313 - accuracy: 0.2443 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.8163 - val_accuracy: 0.2512 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 2/10
# 323/323 [==============================] - 87s 270ms/step - loss: 1.8221 - accuracy: 0.2480 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.8144 - val_accuracy: 0.2512 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 3/10
# 323/323 [==============================] - 98s 304ms/step - loss: 1.8172 - accuracy: 0.2496 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.8064 - val_accuracy: 0.2512 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 4/10
# 323/323 [==============================] - 102s 315ms/step - loss: 1.8062 - accuracy: 0.2521 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7836 - val_accuracy: 0.2586 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 5/10
# 323/323 [==============================] - 99s 305ms/step - loss: 1.7942 - accuracy: 0.2540 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7719 - val_accuracy: 0.2682 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 6/10
# 323/323 [==============================] - 151s 467ms/step - loss: 1.7857 - accuracy: 0.2570 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7612 - val_accuracy: 0.2686 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 7/10
# 323/323 [==============================] - 189s 586ms/step - loss: 1.7732 - accuracy: 0.2644 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7385 - val_accuracy: 0.2908 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 8/10
# 323/323 [==============================] - 204s 631ms/step - loss: 1.7553 - accuracy: 0.2759 - precision_3: 0.0000e+00 - recall_3: 0.0000e+00 - val_loss: 1.7115 - val_accuracy: 0.3169 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00
# Epoch 9/10
# 323/323 [==============================] - 189s 584ms/step - loss: 1.7345 - accuracy: 0.2930 - precision_3: 0.5821 - recall_3: 0.0019 - val_loss: 1.6776 - val_accuracy: 0.3365 - val_precision_3: 1.0000 - val_recall_3: 0.0026
# Epoch 10/10
# 323/323 [==============================] - 234s 722ms/step - loss: 1.7109 - accuracy: 0.3066 - precision_3: 0.5526 - recall_3: 0.0091 - val_loss: 1.6322 - val_accuracy: 0.3539 - val_precision_3: 0.6122 - val_recall_3: 0.0261
# 36/36 [==============================] - 12s 207ms/step
# Metrics for Angry:
# Average Validation Accuracy: 85.50%
# Average Validation Precision: 37.25%
# Average Validation Recall: 5.94%
# Average Validation F1-score: 10.24%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.80%
# Average Validation Precision: 22.50%
# Average Validation Recall: 5.49%
# Average Validation F1-score: 8.82%
#
# Metrics for Happy:
# Average Validation Accuracy: 58.82%
# Average Validation Precision: 35.95%
# Average Validation Recall: 81.80%
# Average Validation F1-score: 49.95%
#
# Metrics for Sad:
# Average Validation Accuracy: 77.36%
# Average Validation Precision: 30.35%
# Average Validation Recall: 23.93%
# Average Validation F1-score: 26.76%
#
# Metrics for Surprise:
# Average Validation Accuracy: 78.06%
# Average Validation Precision: 29.47%
# Average Validation Recall: 21.71%
# Average Validation F1-score: 25.00%
#
# Metrics for Neutral:
# Average Validation Accuracy: 88.77%
# Average Validation Precision: 49.02%
# Average Validation Recall: 49.41%
# Average Validation F1-score: 49.21%
#
# Fold 2/10
# Found 20670 validated image filenames belonging to 7 classes.
# Found 2297 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 323/323 [==============================] - 239s 673ms/step - loss: 1.8337 - accuracy: 0.2455 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.8157 - val_accuracy: 0.2512 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 2/10
# 323/323 [==============================] - 203s 626ms/step - loss: 1.8211 - accuracy: 0.2481 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.8115 - val_accuracy: 0.2512 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 3/10
# 323/323 [==============================] - 207s 639ms/step - loss: 1.8135 - accuracy: 0.2520 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7985 - val_accuracy: 0.2525 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 4/10
# 323/323 [==============================] - 237s 734ms/step - loss: 1.7971 - accuracy: 0.2523 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7909 - val_accuracy: 0.2603 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 5/10
# 323/323 [==============================] - 176s 543ms/step - loss: 1.7908 - accuracy: 0.2527 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7780 - val_accuracy: 0.2573 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 6/10
# 323/323 [==============================] - 192s 594ms/step - loss: 1.7814 - accuracy: 0.2575 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7660 - val_accuracy: 0.2621 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 7/10
# 323/323 [==============================] - 219s 676ms/step - loss: 1.7708 - accuracy: 0.2631 - precision_4: 0.0000e+00 - recall_4: 0.0000e+00 - val_loss: 1.7495 - val_accuracy: 0.2852 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 8/10
# 323/323 [==============================] - 198s 611ms/step - loss: 1.7551 - accuracy: 0.2739 - precision_4: 0.5000 - recall_4: 1.4514e-04 - val_loss: 1.7289 - val_accuracy: 0.3182 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00
# Epoch 9/10
# 323/323 [==============================] - 181s 560ms/step - loss: 1.7328 - accuracy: 0.2937 - precision_4: 0.5778 - recall_4: 0.0025 - val_loss: 1.6893 - val_accuracy: 0.3357 - val_precision_4: 0.6429 - val_recall_4: 0.0039
# Epoch 10/10
# 323/323 [==============================] - 197s 609ms/step - loss: 1.7176 - accuracy: 0.3019 - precision_4: 0.5519 - recall_4: 0.0098 - val_loss: 1.6621 - val_accuracy: 0.3570 - val_precision_4: 0.6739 - val_recall_4: 0.0135
# 36/36 [==============================] - 6s 127ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.83%
# Average Validation Precision: 34.25%
# Average Validation Recall: 14.69%
# Average Validation F1-score: 18.51%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.54%
# Average Validation Precision: 21.96%
# Average Validation Recall: 5.95%
# Average Validation F1-score: 9.34%
#
# Metrics for Happy:
# Average Validation Accuracy: 60.95%
# Average Validation Precision: 37.10%
# Average Validation Recall: 79.12%
# Average Validation F1-score: 50.46%
#
# Metrics for Sad:
# Average Validation Accuracy: 78.23%
# Average Validation Precision: 30.79%
# Average Validation Recall: 20.65%
# Average Validation F1-score: 24.55%
#
# Metrics for Surprise:
# Average Validation Accuracy: 78.21%
# Average Validation Precision: 30.33%
# Average Validation Recall: 22.77%
# Average Validation F1-score: 26.01%
#
# Metrics for Neutral:
# Average Validation Accuracy: 87.85%
# Average Validation Precision: 45.54%
# Average Validation Recall: 48.72%
# Average Validation F1-score: 47.03%
#
# Fold 3/10
# Found 20670 validated image filenames belonging to 7 classes.
# Found 2297 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 323/323 [==============================] - 227s 653ms/step - loss: 1.8328 - accuracy: 0.2448 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.8160 - val_accuracy: 0.2512 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 2/10
# 323/323 [==============================] - 206s 636ms/step - loss: 1.8187 - accuracy: 0.2488 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.8038 - val_accuracy: 0.2503 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 3/10
# 323/323 [==============================] - 196s 606ms/step - loss: 1.8042 - accuracy: 0.2517 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7891 - val_accuracy: 0.2529 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 4/10
# 323/323 [==============================] - 187s 578ms/step - loss: 1.7912 - accuracy: 0.2552 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7714 - val_accuracy: 0.2647 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 5/10
# 323/323 [==============================] - 197s 608ms/step - loss: 1.7790 - accuracy: 0.2587 - precision_5: 0.0000e+00 - recall_5: 0.0000e+00 - val_loss: 1.7592 - val_accuracy: 0.2834 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 6/10
# 323/323 [==============================] - 203s 627ms/step - loss: 1.7660 - accuracy: 0.2743 - precision_5: 1.0000 - recall_5: 9.6759e-05 - val_loss: 1.7336 - val_accuracy: 0.3169 - val_precision_5: 0.0000e+00 - val_recall_5: 0.0000e+00
# Epoch 7/10
# 323/323 [==============================] - 208s 643ms/step - loss: 1.7451 - accuracy: 0.2895 - precision_5: 0.4444 - recall_5: 9.6759e-04 - val_loss: 1.6992 - val_accuracy: 0.3422 - val_precision_5: 1.0000 - val_recall_5: 4.3535e-04
# Epoch 8/10
# 323/323 [==============================] - 196s 606ms/step - loss: 1.7202 - accuracy: 0.3075 - precision_5: 0.5412 - recall_5: 0.0073 - val_loss: 1.6505 - val_accuracy: 0.3526 - val_precision_5: 0.7812 - val_recall_5: 0.0109
# Epoch 9/10
# 323/323 [==============================] - 197s 610ms/step - loss: 1.7029 - accuracy: 0.3173 - precision_5: 0.5318 - recall_5: 0.0194 - val_loss: 1.6524 - val_accuracy: 0.3609 - val_precision_5: 0.5385 - val_recall_5: 0.0183
# Epoch 10/10
# 323/323 [==============================] - 196s 605ms/step - loss: 1.6828 - accuracy: 0.3276 - precision_5: 0.5994 - recall_5: 0.0362 - val_loss: 1.5960 - val_accuracy: 0.3862 - val_precision_5: 0.7246 - val_recall_5: 0.0527
# 36/36 [==============================] - 9s 185ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.18%
# Average Validation Precision: 34.96%
# Average Validation Recall: 13.54%
# Average Validation F1-score: 18.07%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.89%
# Average Validation Precision: 23.57%
# Average Validation Recall: 5.49%
# Average Validation F1-score: 8.83%
#
# Metrics for Happy:
# Average Validation Accuracy: 64.05%
# Average Validation Precision: 39.67%
# Average Validation Recall: 79.20%
# Average Validation F1-score: 52.74%
#
# Metrics for Sad:
# Average Validation Accuracy: 76.32%
# Average Validation Precision: 30.65%
# Average Validation Recall: 29.05%
# Average Validation F1-score: 28.55%
#
# Metrics for Surprise:
# Average Validation Accuracy: 77.99%
# Average Validation Precision: 29.31%
# Average Validation Recall: 21.92%
# Average Validation F1-score: 25.08%
#
# Metrics for Neutral:
# Average Validation Accuracy: 88.23%
# Average Validation Precision: 47.10%
# Average Validation Recall: 47.97%
# Average Validation F1-score: 47.44%
#
# Fold 4/10
# Found 20670 validated image filenames belonging to 7 classes.
# Found 2297 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 323/323 [==============================] - 213s 609ms/step - loss: 1.8300 - accuracy: 0.2467 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.8113 - val_accuracy: 0.2516 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 2/10
# 323/323 [==============================] - 196s 605ms/step - loss: 1.8191 - accuracy: 0.2502 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.8036 - val_accuracy: 0.2516 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 3/10
# 323/323 [==============================] - 196s 603ms/step - loss: 1.8016 - accuracy: 0.2517 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7844 - val_accuracy: 0.2516 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 4/10
# 323/323 [==============================] - 194s 599ms/step - loss: 1.7899 - accuracy: 0.2515 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7717 - val_accuracy: 0.2556 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 5/10
# 323/323 [==============================] - 194s 600ms/step - loss: 1.7819 - accuracy: 0.2568 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7580 - val_accuracy: 0.2712 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 6/10
# 323/323 [==============================] - 198s 613ms/step - loss: 1.7709 - accuracy: 0.2676 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7426 - val_accuracy: 0.2930 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 7/10
# 323/323 [==============================] - 183s 568ms/step - loss: 1.7547 - accuracy: 0.2811 - precision_6: 0.0000e+00 - recall_6: 0.0000e+00 - val_loss: 1.7099 - val_accuracy: 0.3204 - val_precision_6: 0.0000e+00 - val_recall_6: 0.0000e+00
# Epoch 8/10
# 323/323 [==============================] - 191s 591ms/step - loss: 1.7359 - accuracy: 0.2923 - precision_6: 0.5000 - recall_6: 0.0016 - val_loss: 1.6786 - val_accuracy: 0.3378 - val_precision_6: 0.4444 - val_recall_6: 0.0017
# Epoch 9/10
# 323/323 [==============================] - 196s 604ms/step - loss: 1.7133 - accuracy: 0.3058 - precision_6: 0.5498 - recall_6: 0.0077 - val_loss: 1.6520 - val_accuracy: 0.3548 - val_precision_6: 0.7143 - val_recall_6: 0.0261
# Epoch 10/10
# 323/323 [==============================] - 180s 555ms/step - loss: 1.6963 - accuracy: 0.3184 - precision_6: 0.5916 - recall_6: 0.0217 - val_loss: 1.6329 - val_accuracy: 0.3609 - val_precision_6: 0.7315 - val_recall_6: 0.0344
# 36/36 [==============================] - 7s 150ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.43%
# Average Validation Precision: 33.58%
# Average Validation Recall: 16.50%
# Average Validation F1-score: 20.37%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.40%
# Average Validation Precision: 23.74%
# Average Validation Recall: 7.24%
# Average Validation F1-score: 10.75%
#
# Metrics for Happy:
# Average Validation Accuracy: 66.27%
# Average Validation Precision: 41.54%
# Average Validation Recall: 75.23%
# Average Validation F1-score: 53.07%
#
# Metrics for Sad:
# Average Validation Accuracy: 77.19%
# Average Validation Precision: 30.41%
# Average Validation Recall: 24.87%
# Average Validation F1-score: 25.77%
#
# Metrics for Surprise:
# Average Validation Accuracy: 76.92%
# Average Validation Precision: 29.12%
# Average Validation Recall: 25.83%
# Average Validation F1-score: 26.92%
#
# Metrics for Neutral:
# Average Validation Accuracy: 87.21%
# Average Validation Precision: 44.42%
# Average Validation Recall: 50.44%
# Average Validation F1-score: 46.75%
#
# Fold 5/10
# Found 20670 validated image filenames belonging to 7 classes.
# Found 2297 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 323/323 [==============================] - 198s 518ms/step - loss: 1.8328 - accuracy: 0.2427 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.8178 - val_accuracy: 0.2516 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 2/10
# 323/323 [==============================] - 179s 553ms/step - loss: 1.8203 - accuracy: 0.2493 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.8096 - val_accuracy: 0.2516 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 3/10
# 323/323 [==============================] - 200s 618ms/step - loss: 1.8052 - accuracy: 0.2515 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7836 - val_accuracy: 0.2599 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 4/10
# 323/323 [==============================] - 197s 609ms/step - loss: 1.7916 - accuracy: 0.2502 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7801 - val_accuracy: 0.2569 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 5/10
# 323/323 [==============================] - 201s 623ms/step - loss: 1.7825 - accuracy: 0.2521 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7617 - val_accuracy: 0.2651 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 6/10
# 323/323 [==============================] - 214s 661ms/step - loss: 1.7758 - accuracy: 0.2593 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7462 - val_accuracy: 0.2843 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 7/10
# 323/323 [==============================] - 204s 631ms/step - loss: 1.7572 - accuracy: 0.2800 - precision_7: 0.0000e+00 - recall_7: 0.0000e+00 - val_loss: 1.7257 - val_accuracy: 0.3087 - val_precision_7: 0.0000e+00 - val_recall_7: 0.0000e+00
# Epoch 8/10
# 323/323 [==============================] - 202s 626ms/step - loss: 1.7351 - accuracy: 0.2897 - precision_7: 0.5490 - recall_7: 0.0014 - val_loss: 1.6938 - val_accuracy: 0.3274 - val_precision_7: 0.5862 - val_recall_7: 0.0074
# Epoch 9/10
# 323/323 [==============================] - 193s 598ms/step - loss: 1.7103 - accuracy: 0.3109 - precision_7: 0.5489 - recall_7: 0.0084 - val_loss: 1.6405 - val_accuracy: 0.3626 - val_precision_7: 0.6538 - val_recall_7: 0.0148
# Epoch 10/10
# 323/323 [==============================] - 209s 645ms/step - loss: 1.6913 - accuracy: 0.3233 - precision_7: 0.5935 - recall_7: 0.0246 - val_loss: 1.6066 - val_accuracy: 0.3740 - val_precision_7: 0.7018 - val_recall_7: 0.0522
# 36/36 [==============================] - 8s 169ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.53%
# Average Validation Precision: 33.57%
# Average Validation Recall: 16.46%
# Average Validation F1-score: 20.69%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.78%
# Average Validation Precision: 23.44%
# Average Validation Recall: 6.04%
# Average Validation F1-score: 9.06%
#
# Metrics for Happy:
# Average Validation Accuracy: 66.30%
# Average Validation Precision: 41.49%
# Average Validation Recall: 76.03%
# Average Validation F1-score: 53.32%
#
# Metrics for Sad:
# Average Validation Accuracy: 77.00%
# Average Validation Precision: 30.04%
# Average Validation Recall: 24.89%
# Average Validation F1-score: 25.94%
#
# Metrics for Surprise:
# Average Validation Accuracy: 77.21%
# Average Validation Precision: 29.61%
# Average Validation Recall: 25.58%
# Average Validation F1-score: 27.07%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.99%
# Average Validation Precision: 43.77%
# Average Validation Recall: 52.24%
# Average Validation F1-score: 47.13%
#
# Fold 6/10
# Found 20670 validated image filenames belonging to 7 classes.
# Found 2297 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 323/323 [==============================] - 219s 632ms/step - loss: 1.8303 - accuracy: 0.2459 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.8154 - val_accuracy: 0.2512 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 2/10
# 323/323 [==============================] - 196s 607ms/step - loss: 1.8187 - accuracy: 0.2486 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.8093 - val_accuracy: 0.2512 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 3/10
# 323/323 [==============================] - 193s 596ms/step - loss: 1.8070 - accuracy: 0.2512 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7938 - val_accuracy: 0.2564 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 4/10
# 323/323 [==============================] - 203s 627ms/step - loss: 1.7930 - accuracy: 0.2522 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7884 - val_accuracy: 0.2447 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 5/10
# 323/323 [==============================] - 200s 619ms/step - loss: 1.7848 - accuracy: 0.2566 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7872 - val_accuracy: 0.2569 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 6/10
# 323/323 [==============================] - 200s 617ms/step - loss: 1.7760 - accuracy: 0.2584 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7632 - val_accuracy: 0.2647 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 7/10
# 323/323 [==============================] - 198s 613ms/step - loss: 1.7617 - accuracy: 0.2727 - precision_8: 0.0000e+00 - recall_8: 0.0000e+00 - val_loss: 1.7407 - val_accuracy: 0.2886 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 8/10
# 323/323 [==============================] - 189s 585ms/step - loss: 1.7448 - accuracy: 0.2845 - precision_8: 0.7778 - recall_8: 3.3866e-04 - val_loss: 1.7158 - val_accuracy: 0.3182 - val_precision_8: 0.0000e+00 - val_recall_8: 0.0000e+00
# Epoch 9/10
# 323/323 [==============================] - 179s 552ms/step - loss: 1.7232 - accuracy: 0.3044 - precision_8: 0.5238 - recall_8: 0.0032 - val_loss: 1.7115 - val_accuracy: 0.3013 - val_precision_8: 0.6786 - val_recall_8: 0.0083
# Epoch 10/10
# 323/323 [==============================] - 2622s 8s/step - loss: 1.7021 - accuracy: 0.3148 - precision_8: 0.5582 - recall_8: 0.0125 - val_loss: 1.6650 - val_accuracy: 0.3370 - val_precision_8: 0.5980 - val_recall_8: 0.0266
# 36/36 [==============================] - 9s 196ms/step
# Metrics for Angry:
# Average Validation Accuracy: 83.88%
# Average Validation Precision: 34.18%
# Average Validation Recall: 14.56%
# Average Validation F1-score: 18.71%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.88%
# Average Validation Precision: 23.24%
# Average Validation Recall: 5.64%
# Average Validation F1-score: 8.60%
#
# Metrics for Happy:
# Average Validation Accuracy: 65.53%
# Average Validation Precision: 40.73%
# Average Validation Recall: 75.75%
# Average Validation F1-score: 52.65%
#
# Metrics for Sad:
# Average Validation Accuracy: 76.27%
# Average Validation Precision: 29.45%
# Average Validation Recall: 26.18%
# Average Validation F1-score: 26.49%
#
# Metrics for Surprise:
# Average Validation Accuracy: 77.86%
# Average Validation Precision: 29.93%
# Average Validation Recall: 23.09%
# Average Validation F1-score: 25.20%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.40%
# Average Validation Precision: 42.29%
# Average Validation Recall: 53.12%
# Average Validation F1-score: 46.52%
#
# Fold 7/10
# Found 20670 validated image filenames belonging to 7 classes.
# Found 2297 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 323/323 [==============================] - 211s 605ms/step - loss: 1.8349 - accuracy: 0.2449 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8153 - val_accuracy: 0.2512 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 2/10
# 323/323 [==============================] - 178s 552ms/step - loss: 1.8223 - accuracy: 0.2485 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.8101 - val_accuracy: 0.2516 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 3/10
# 323/323 [==============================] - 195s 604ms/step - loss: 1.8076 - accuracy: 0.2521 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7967 - val_accuracy: 0.2560 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 4/10
# 323/323 [==============================] - 204s 631ms/step - loss: 1.7925 - accuracy: 0.2513 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7842 - val_accuracy: 0.2595 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 5/10
# 323/323 [==============================] - 190s 587ms/step - loss: 1.7834 - accuracy: 0.2579 - precision_9: 0.0000e+00 - recall_9: 0.0000e+00 - val_loss: 1.7814 - val_accuracy: 0.2647 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 6/10
# 323/323 [==============================] - 174s 536ms/step - loss: 1.7709 - accuracy: 0.2673 - precision_9: 1.0000 - recall_9: 4.8379e-05 - val_loss: 1.7539 - val_accuracy: 0.3008 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 7/10
# 323/323 [==============================] - 187s 578ms/step - loss: 1.7568 - accuracy: 0.2786 - precision_9: 0.2500 - recall_9: 9.6759e-05 - val_loss: 1.7255 - val_accuracy: 0.3156 - val_precision_9: 0.0000e+00 - val_recall_9: 0.0000e+00
# Epoch 8/10
# 323/323 [==============================] - 185s 571ms/step - loss: 1.7365 - accuracy: 0.2950 - precision_9: 0.5437 - recall_9: 0.0027 - val_loss: 1.6825 - val_accuracy: 0.3339 - val_precision_9: 1.0000 - val_recall_9: 4.3535e-04
# Epoch 9/10
# 323/323 [==============================] - 199s 617ms/step - loss: 1.7130 - accuracy: 0.3138 - precision_9: 0.5958 - recall_9: 0.0125 - val_loss: 1.6483 - val_accuracy: 0.3487 - val_precision_9: 0.7273 - val_recall_9: 0.0174
# Epoch 10/10
# 323/323 [==============================] - 4029s 13s/step - loss: 1.6908 - accuracy: 0.3243 - precision_9: 0.6041 - recall_9: 0.0272 - val_loss: 1.6227 - val_accuracy: 0.3687 - val_precision_9: 0.7259 - val_recall_9: 0.0427
# 36/36 [==============================] - 6s 128ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.15%
# Average Validation Precision: 34.59%
# Average Validation Recall: 12.92%
# Average Validation F1-score: 16.86%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.87%
# Average Validation Precision: 22.77%
# Average Validation Recall: 5.49%
# Average Validation F1-score: 8.43%
#
# Metrics for Happy:
# Average Validation Accuracy: 66.14%
# Average Validation Precision: 41.21%
# Average Validation Recall: 75.75%
# Average Validation F1-score: 53.09%
#
# Metrics for Sad:
# Average Validation Accuracy: 76.11%
# Average Validation Precision: 29.55%
# Average Validation Recall: 27.18%
# Average Validation F1-score: 27.22%
#
# Metrics for Surprise:
# Average Validation Accuracy: 77.64%
# Average Validation Precision: 29.77%
# Average Validation Recall: 23.75%
# Average Validation F1-score: 25.64%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.12%
# Average Validation Precision: 41.53%
# Average Validation Recall: 53.74%
# Average Validation F1-score: 46.30%
#
# Fold 8/10
# Found 20671 validated image filenames belonging to 7 classes.
# Found 2296 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 323/323 [==============================] - 181s 525ms/step - loss: 1.8322 - accuracy: 0.2453 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.8169 - val_accuracy: 0.2513 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 2/10
# 323/323 [==============================] - 165s 510ms/step - loss: 1.8226 - accuracy: 0.2490 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.8067 - val_accuracy: 0.2513 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 3/10
# 323/323 [==============================] - 160s 493ms/step - loss: 1.8108 - accuracy: 0.2492 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7894 - val_accuracy: 0.2544 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 4/10
# 323/323 [==============================] - 153s 474ms/step - loss: 1.7956 - accuracy: 0.2540 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7785 - val_accuracy: 0.2539 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 5/10
# 323/323 [==============================] - 3814s 12s/step - loss: 1.7882 - accuracy: 0.2544 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7735 - val_accuracy: 0.2548 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 6/10
# 323/323 [==============================] - 153s 475ms/step - loss: 1.7789 - accuracy: 0.2575 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7549 - val_accuracy: 0.2696 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 7/10
# 323/323 [==============================] - 158s 488ms/step - loss: 1.7600 - accuracy: 0.2731 - precision_10: 0.0000e+00 - recall_10: 0.0000e+00 - val_loss: 1.7233 - val_accuracy: 0.2957 - val_precision_10: 0.0000e+00 - val_recall_10: 0.0000e+00
# Epoch 8/10
# 323/323 [==============================] - 153s 472ms/step - loss: 1.7410 - accuracy: 0.2869 - precision_10: 0.5227 - recall_10: 0.0011 - val_loss: 1.6960 - val_accuracy: 0.3288 - val_precision_10: 0.4444 - val_recall_10: 0.0017
# Epoch 9/10
# 323/323 [==============================] - 156s 482ms/step - loss: 1.7210 - accuracy: 0.2980 - precision_10: 0.5534 - recall_10: 0.0055 - val_loss: 1.6750 - val_accuracy: 0.3419 - val_precision_10: 0.7067 - val_recall_10: 0.0231
# Epoch 10/10
# 323/323 [==============================] - 157s 485ms/step - loss: 1.6942 - accuracy: 0.3174 - precision_10: 0.5721 - recall_10: 0.0184 - val_loss: 1.6271 - val_accuracy: 0.3528 - val_precision_10: 0.7411 - val_recall_10: 0.0723
# 36/36 [==============================] - 6s 131ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.38%
# Average Validation Precision: 36.10%
# Average Validation Recall: 12.13%
# Average Validation F1-score: 16.19%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.86%
# Average Validation Precision: 23.48%
# Average Validation Recall: 5.91%
# Average Validation F1-score: 9.07%
#
# Metrics for Happy:
# Average Validation Accuracy: 64.83%
# Average Validation Precision: 40.37%
# Average Validation Recall: 76.92%
# Average Validation F1-score: 52.59%
#
# Metrics for Sad:
# Average Validation Accuracy: 76.77%
# Average Validation Precision: 30.37%
# Average Validation Recall: 25.01%
# Average Validation F1-score: 25.75%
#
# Metrics for Surprise:
# Average Validation Accuracy: 77.52%
# Average Validation Precision: 29.65%
# Average Validation Recall: 24.05%
# Average Validation F1-score: 25.86%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.43%
# Average Validation Precision: 42.38%
# Average Validation Recall: 53.37%
# Average Validation F1-score: 46.70%
#
# Fold 9/10
# Found 20671 validated image filenames belonging to 7 classes.
# Found 2296 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 323/323 [==============================] - 175s 498ms/step - loss: 1.8360 - accuracy: 0.2411 - precision_11: 0.0000e+00 - recall_11: 0.0000e+00 - val_loss: 1.8151 - val_accuracy: 0.2513 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00
# Epoch 2/10
# 323/323 [==============================] - 165s 509ms/step - loss: 1.8190 - accuracy: 0.2488 - precision_11: 0.0000e+00 - recall_11: 0.0000e+00 - val_loss: 1.8076 - val_accuracy: 0.2539 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00
# Epoch 3/10
# 323/323 [==============================] - 127s 393ms/step - loss: 1.8049 - accuracy: 0.2519 - precision_11: 0.0000e+00 - recall_11: 0.0000e+00 - val_loss: 1.7903 - val_accuracy: 0.2548 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00
# Epoch 4/10
# 323/323 [==============================] - 117s 360ms/step - loss: 1.7910 - accuracy: 0.2568 - precision_11: 0.0000e+00 - recall_11: 0.0000e+00 - val_loss: 1.7859 - val_accuracy: 0.2552 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00
# Epoch 5/10
# 323/323 [==============================] - 119s 368ms/step - loss: 1.7804 - accuracy: 0.2601 - precision_11: 0.0000e+00 - recall_11: 0.0000e+00 - val_loss: 1.7630 - val_accuracy: 0.2609 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00
# Epoch 6/10
# 323/323 [==============================] - 124s 383ms/step - loss: 1.7660 - accuracy: 0.2713 - precision_11: 0.2500 - recall_11: 4.8377e-05 - val_loss: 1.7379 - val_accuracy: 0.2892 - val_precision_11: 0.0000e+00 - val_recall_11: 0.0000e+00
# Epoch 7/10
# 323/323 [==============================] - 122s 377ms/step - loss: 1.7457 - accuracy: 0.2875 - precision_11: 0.6452 - recall_11: 9.6754e-04 - val_loss: 1.7094 - val_accuracy: 0.3036 - val_precision_11: 0.7500 - val_recall_11: 0.0013
# Epoch 8/10
# 323/323 [==============================] - 125s 386ms/step - loss: 1.7272 - accuracy: 0.3009 - precision_11: 0.5550 - recall_11: 0.0059 - val_loss: 1.6764 - val_accuracy: 0.3336 - val_precision_11: 0.5769 - val_recall_11: 0.0065
# Epoch 9/10
# 323/323 [==============================] - 122s 378ms/step - loss: 1.7026 - accuracy: 0.3173 - precision_11: 0.5926 - recall_11: 0.0170 - val_loss: 1.6422 - val_accuracy: 0.3480 - val_precision_11: 0.6452 - val_recall_11: 0.0436
# Epoch 10/10
# 323/323 [==============================] - 93s 286ms/step - loss: 1.6833 - accuracy: 0.3337 - precision_11: 0.6019 - recall_11: 0.0342 - val_loss: 1.6133 - val_accuracy: 0.3689 - val_precision_11: 0.6708 - val_recall_11: 0.0710
# 36/36 [==============================] - 4s 91ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.45%
# Average Validation Precision: 36.17%
# Average Validation Recall: 11.89%
# Average Validation F1-score: 16.14%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 83.97%
# Average Validation Precision: 24.05%
# Average Validation Recall: 5.73%
# Average Validation F1-score: 8.89%
#
# Metrics for Happy:
# Average Validation Accuracy: 65.10%
# Average Validation Precision: 40.54%
# Average Validation Recall: 77.08%
# Average Validation F1-score: 52.82%
#
# Metrics for Sad:
# Average Validation Accuracy: 76.44%
# Average Validation Precision: 30.09%
# Average Validation Recall: 25.84%
# Average Validation F1-score: 26.22%
#
# Metrics for Surprise:
# Average Validation Accuracy: 77.86%
# Average Validation Precision: 30.10%
# Average Validation Recall: 23.10%
# Average Validation F1-score: 25.34%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.13%
# Average Validation Precision: 41.71%
# Average Validation Recall: 54.47%
# Average Validation F1-score: 46.64%
#
# Fold 10/10
# Found 20671 validated image filenames belonging to 7 classes.
# Found 2296 validated image filenames belonging to 7 classes.
# Epoch 1/10
# 323/323 [==============================] - 91s 269ms/step - loss: 1.8331 - accuracy: 0.2455 - precision_12: 0.0000e+00 - recall_12: 0.0000e+00 - val_loss: 1.8144 - val_accuracy: 0.2513 - val_precision_12: 0.0000e+00 - val_recall_12: 0.0000e+00
# Epoch 2/10
# 323/323 [==============================] - 87s 268ms/step - loss: 1.8202 - accuracy: 0.2485 - precision_12: 0.0000e+00 - recall_12: 0.0000e+00 - val_loss: 1.8123 - val_accuracy: 0.2513 - val_precision_12: 0.0000e+00 - val_recall_12: 0.0000e+00
# Epoch 3/10
# 323/323 [==============================] - 65s 200ms/step - loss: 1.8145 - accuracy: 0.2509 - precision_12: 0.0000e+00 - recall_12: 0.0000e+00 - val_loss: 1.7999 - val_accuracy: 0.2535 - val_precision_12: 0.0000e+00 - val_recall_12: 0.0000e+00
# Epoch 4/10
# 323/323 [==============================] - 54s 166ms/step - loss: 1.7983 - accuracy: 0.2525 - precision_12: 0.0000e+00 - recall_12: 0.0000e+00 - val_loss: 1.7828 - val_accuracy: 0.2600 - val_precision_12: 0.0000e+00 - val_recall_12: 0.0000e+00
# Epoch 5/10
# 323/323 [==============================] - 53s 165ms/step - loss: 1.7887 - accuracy: 0.2550 - precision_12: 0.0000e+00 - recall_12: 0.0000e+00 - val_loss: 1.7750 - val_accuracy: 0.2578 - val_precision_12: 0.0000e+00 - val_recall_12: 0.0000e+00
# Epoch 6/10
# 323/323 [==============================] - 54s 168ms/step - loss: 1.7802 - accuracy: 0.2611 - precision_12: 0.0000e+00 - recall_12: 0.0000e+00 - val_loss: 1.7573 - val_accuracy: 0.2831 - val_precision_12: 0.0000e+00 - val_recall_12: 0.0000e+00
# Epoch 7/10
# 323/323 [==============================] - 52s 161ms/step - loss: 1.7684 - accuracy: 0.2686 - precision_12: 0.0000e+00 - recall_12: 0.0000e+00 - val_loss: 1.7295 - val_accuracy: 0.3162 - val_precision_12: 0.0000e+00 - val_recall_12: 0.0000e+00
# Epoch 8/10
# 323/323 [==============================] - 52s 161ms/step - loss: 1.7458 - accuracy: 0.2895 - precision_12: 0.5556 - recall_12: 4.8377e-04 - val_loss: 1.6974 - val_accuracy: 0.3288 - val_precision_12: 0.0000e+00 - val_recall_12: 0.0000e+00
# Epoch 9/10
# 323/323 [==============================] - 52s 162ms/step - loss: 1.7219 - accuracy: 0.3056 - precision_12: 0.5660 - recall_12: 0.0064 - val_loss: 1.6626 - val_accuracy: 0.3136 - val_precision_12: 0.6290 - val_recall_12: 0.0510
# Epoch 10/10
# 323/323 [==============================] - 53s 166ms/step - loss: 1.6998 - accuracy: 0.3194 - precision_12: 0.5735 - recall_12: 0.0208 - val_loss: 1.6348 - val_accuracy: 0.3358 - val_precision_12: 0.6445 - val_recall_12: 0.0845
# 36/36 [==============================] - 2s 59ms/step
# Metrics for Angry:
# Average Validation Accuracy: 84.34%
# Average Validation Precision: 35.21%
# Average Validation Recall: 11.80%
# Average Validation F1-score: 16.08%
#
# Metrics for Disgust:
# Average Validation Accuracy: 98.48%
# Average Validation Precision: 0.00%
# Average Validation Recall: 0.00%
# Average Validation F1-score: 0.00%
#
# Metrics for Fear:
# Average Validation Accuracy: 84.10%
# Average Validation Precision: 24.44%
# Average Validation Recall: 5.37%
# Average Validation F1-score: 8.40%
#
# Metrics for Happy:
# Average Validation Accuracy: 63.79%
# Average Validation Precision: 39.79%
# Average Validation Recall: 78.19%
# Average Validation F1-score: 52.34%
#
# Metrics for Sad:
# Average Validation Accuracy: 76.88%
# Average Validation Precision: 30.11%
# Average Validation Recall: 24.09%
# Average Validation F1-score: 24.90%
#
# Metrics for Surprise:
# Average Validation Accuracy: 77.90%
# Average Validation Precision: 29.92%
# Average Validation Recall: 22.67%
# Average Validation F1-score: 25.07%
#
# Metrics for Neutral:
# Average Validation Accuracy: 86.41%
# Average Validation Precision: 42.50%
# Average Validation Recall: 53.53%
# Average Validation F1-score: 46.70%
#
# Overall Average Metrics:
# Average Validation Accuracy: 81.70%
# Average Validation Precision: 28.85%
# Average Validation Recall: 27.95%
# Average Validation F1-score: 24.78%

# %% [markdown]
# Confusion Matrix

# %%
# Print confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Create a DataFrame for the confusion matrix
conf_df = pd.DataFrame({'TP': np.diag(conf_matrix),
                        'FP': np.sum(conf_matrix, axis=0) - np.diag(conf_matrix),
                        'FN': np.sum(conf_matrix, axis=1) - np.diag(conf_matrix),
                        'TN': np.sum(conf_matrix) - (np.diag(conf_matrix) + (np.sum(conf_matrix, axis=0) - np.diag(conf_matrix)) + (np.sum(conf_matrix, axis=1) - np.diag(conf_matrix)))})

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_df, annot=True, cmap='PuRd', fmt='d')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# Confusion Matrix:
# [[ 35   0   5 194  18  43  25]
#  [  1   0   0  28   1   3   2]
#  [ 29   0   7 197  11  42  41]
#  [ 14   0   4 509  11  22  17]
#  [ 16   0   0 277  33  56  15]
#  [ 24   0   6 242  26  73  16]
#  [ 13   0   3  95   9  19 114]]
